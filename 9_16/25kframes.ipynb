# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import torch
import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx

import numpy as np
import matplotlib.pyplot as plt

# %%
traj = md.load('../../xtc_files/50000eql2.xtc', top='../../xtc_files/conf.gro')

# %%
# converting traj as traj with only 5000 frames
traj=traj[::2]

# %%
# creating the frame feature matrix
nframes = traj.xyz.shape[0]
natoms=traj.topology.residue(0).n_atoms
nmols=traj.topology.n_residues
frame_feature=[]
for i in range(nframes):
    com_pos=[] # position of Center of Mass of each molecule
    for res in range(nmols):
        com_pos.append(traj.xyz[i][res*natoms:(res+1)*natoms].mean(axis=0))
    frame_feature.append(com_pos)
frame_feature=np.array(frame_feature)
print(frame_feature.shape)
# Out:
# (25001, 592, 3)

# %%
# creating the edge index matrix
cutoff=0.5
all_edge_list=[]
for i in range(nframes):
    fromlist=[]
    tolist=[]
    for j in range(nmols):
        for k in range(j+1,nmols):
            if np.linalg.norm(frame_feature[i][j]-frame_feature[i][k])<cutoff:
                fromlist.append(j)
                tolist.append(k)
                tolist.append(j)
                fromlist.append(k)
    edgelist=np.array([fromlist,tolist]).astype(np.int64)
    all_edge_list.append(edgelist)
print(len(all_edge_list))
# Out:
# 25001

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index
frame = 10
plt.figure(figsize=(15,10))
adj_binary = convert_to_adj(all_edge_list[frame], num_nodes=592)
indices = torch.where(adj_binary)
G = nx.Graph()
edges = [(i, j) for i, j in zip(indices[0].tolist(), indices[1].tolist()) if i != j]
G.add_edges_from(edges)
nx.draw_networkx(G)

# %%
graphs = []
for frame in range(nframes):
    g = data.Data(x=torch.tensor(frame_feature[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
    graphs.append(g)

print(graphs[0])
# Out:
# Data(x=[592, 3], edge_index=[2, 8126], y=[1])

# %%
# import model.
from model import *

# %%
input_dim = graphs[0].num_features
output_dim = 2
lr=1e-4
epochs=100
batch_size=1
model=VGAE(VariationalGCNEncoder(input_dim, output_dim),
           VariationalGCNDecoder(output_dim,input_dim))
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
from pytorch3d.loss import chamfer_distance

# %%
train_loader_set = DataLoader(graphs[:int(nframes*0.6)], batch_size=batch_size, shuffle=True)
validation_loader_set = DataLoader(graphs[int(nframes*0.6):int(nframes*0.8)], batch_size=batch_size, shuffle=True)
test_loader_set = DataLoader(graphs[int(nframes*0.8):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    closs_all=0
    for data in train_loader_set:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)
        out2=decoded_x.reshape(1,592,3)
        in2=data.x.reshape(1,592,3)
        closs=chamfer_distance(out2,in2)
        # print(closs[0])
        closs=closs[0]
        closs=torch.tensor(closs, dtype=torch.float32)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        # loss = FeatureLoss + EdgeLoss 
        loss = FeatureLoss + EdgeLoss + closs
        loss = loss 
        closs_all+=float(closs)
        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)

        loss.backward()
        optimizer.step()

        

    return loss_all / len(train_loader_set.dataset),closs_all/len(train_loader_set.dataset), feature_loss_all / len(train_loader_set.dataset), edge_loss_all / len(train_loader_set.dataset), kl_loss_all / len(train_loader_set.dataset)

# %%
total_train_losses = []
feature_train_losses = []
edge_train_losses = []
kl_train_losses = []
closs_train_losses=[]

# validation will be done after training
# training done now
for epoch in range(1,epochs+1):
    tloss,cdloss,floss,eloss,klloss = train()
    print(f'Epoch: {epoch:03d}')
    print(f'Train Loss: {tloss:.4f}, Chamfer Loss: {cdloss:.4f}, Feature Loss: {floss:.4f}, Edge Loss: {eloss:.4f}, KL Loss: {klloss:.4f}')
    total_train_losses.append(tloss)
    feature_train_losses.append(floss)
    edge_train_losses.append(eloss)
    kl_train_losses.append(klloss)
    closs_train_losses.append(cdloss)
# Out:
# /tmp/ipykernel_3846/1287167025.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   closs=torch.tensor(closs, dtype=torch.float32)
# Epoch: 001
# Train Loss: 1.3637, Chamfer Loss: 0.8998, Feature Loss: 0.4638, Edge Loss: 0.0000, KL Loss: 0.0043
# Epoch: 002
# Train Loss: 0.5458, Chamfer Loss: 0.3537, Feature Loss: 0.1922, Edge Loss: 0.0000, KL Loss: 0.0129
# Epoch: 003
# Train Loss: 0.4243, Chamfer Loss: 0.2546, Feature Loss: 0.1697, Edge Loss: 0.0000, KL Loss: 0.0135
# Epoch: 004
# Train Loss: 0.3834, Chamfer Loss: 0.2253, Feature Loss: 0.1580, Edge Loss: 0.0000, KL Loss: 0.0145
# Epoch: 005
# Train Loss: 0.3307, Chamfer Loss: 0.1894, Feature Loss: 0.1414, Edge Loss: 0.0000, KL Loss: 0.0180
# Epoch: 006
# Train Loss: 0.2995, Chamfer Loss: 0.1690, Feature Loss: 0.1306, Edge Loss: 0.0000, KL Loss: 0.0203
# Epoch: 007
# Train Loss: 0.2942, Chamfer Loss: 0.1683, Feature Loss: 0.1259, Edge Loss: 0.0000, KL Loss: 0.0227
Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0737
# Epoch: 092
# Train Loss: 0.2549, Chamfer Loss: 0.1519, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0740
# Epoch: 093
# Train Loss: 0.2547, Chamfer Loss: 0.1518, Feature Loss: 0.1029, Edge Loss: 0.0000, KL Loss: 0.0742
# Epoch: 094
# Train Loss: 0.2546, Chamfer Loss: 0.1517, Feature Loss: 0.1029, Edge Loss: 0.0000, KL Loss: 0.0748
# Epoch: 095
# Train Loss: 0.2544, Chamfer Loss: 0.1516, Feature Loss: 0.1028, Edge Loss: 0.0000, KL Loss: 0.0752
# Epoch: 096
# Train Loss: 0.2542, Chamfer Loss: 0.1514, Feature Loss: 0.1027, Edge Loss: 0.0000, KL Loss: 0.0753
# Epoch: 097
# Train Loss: 0.2540, Chamfer Loss: 0.1513, Feature Loss: 0.1027, Edge Loss: 0.0000, KL Loss: 0.0755
# Epoch: 098
# Train Loss: 0.2538, Chamfer Loss: 0.1512, Feature Loss: 0.1026, Edge Loss: 0.0000, KL Loss: 0.0756
# Epoch: 099
# Train Loss: 0.2536, Chamfer Loss: 0.1511, Feature Loss: 0.1025, Edge Loss: 0.0000, KL Loss: 0.0756
# Epoch: 100
# Train Loss: 0.2534, Chamfer Loss: 0.1510, Feature Loss: 0.1025, Edge Loss: 0.0000, KL Loss: 0.0763

# %%
# writing a validate function
def validate():
    model.eval()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    closs_all=0
    for data in validation_loader_set:
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)
        out2=decoded_x.reshape(1,592,3)
        in2=data.x.reshape(1,592,3)
        closs=chamfer_distance(out2,in2)
        closs=closs[0]
        closs=torch.tensor(closs, dtype=torch.float32)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss + closs
        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)
        closs_all+=float(closs)
    return loss_all / len(validation_loader_set.dataset),closs_all/len(validation_loader_set.dataset), feature_loss_all / len(validation_loader_set.dataset), edge_loss_all / len(validation_loader_set.dataset), kl_loss_all / len(validation_loader_set.dataset)

# %%
# validating the model 
total_val_losses = []
feature_val_losses = []
edge_val_losses = []
kl_val_losses = []
closs_val_losses=[]
for epoch in range(1,epochs+1):
    vtloss,vcdloss,vfloss,veloss,vklloss = validate()
    print(f'Epoch: {epoch:03d}')
    print(f'Validation Loss: {vtloss:.4f}, Chamfer Loss: {vcdloss:.4f}, Feature Loss: {vfloss:.4f}, Edge Loss: {veloss:.4f}, KL Loss: {vklloss:.4f}')
    total_val_losses.append(vtloss)
    feature_val_losses.append(vfloss)
    edge_val_losses.append(veloss)
    kl_val_losses.append(vklloss)
    closs_val_losses.append(vcdloss)
# Out:
# /tmp/ipykernel_3846/3429122802.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   closs=torch.tensor(closs, dtype=torch.float32)
# Epoch: 001
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 002
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 003
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 004
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 005
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 006
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 007
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 008
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 009
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 010
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 011
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 012
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 013
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 014
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 015
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 016
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 017
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 018
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 019
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 020
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 021
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 022
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 023
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 024
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 025
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 026
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 027
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 028
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 029
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 030
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 031
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 032
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 033
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 034
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 035
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 036
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 037
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 038
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 039
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 040
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 041
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 042
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 043
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 044
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 045
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 046
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 047
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 048
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 049
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 050
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 051
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 052
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 053
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 054
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 055
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 056
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 057
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 058
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 059
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 060
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 061
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 062
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 063
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 064
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 065
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 066
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 067
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 068
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 069
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 070
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 071
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 072
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 073
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 074
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 075
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 076
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 077
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 078
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 079
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 080
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 081
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 082
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 083
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 084
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 085
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 086
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 087
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 088
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 089
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 090
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 091
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 092
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 093
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 094
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 095
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 096
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 097
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 098
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 099
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 100
# Validation Loss: 0.2540, Chamfer Loss: 0.1510, Feature Loss: 0.1030, Edge Loss: 0.0000, KL Loss: 0.0765

# %%
# test function 
def test():
    model.eval()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    closs_all=0
    for data in test_loader_set:
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)
        out2=decoded_x.reshape(1,592,3)
        in2=data.x.reshape(1,592,3)
        closs=chamfer_distance(out2,in2)
        closs=closs[0]
        closs=torch.tensor(closs, dtype=torch.float32)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss + closs
        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)
        closs_all+=float(closs)
    return loss_all / len(test_loader_set.dataset),closs_all/len(test_loader_set.dataset), feature_loss_all / len(test_loader_set.dataset), edge_loss_all / len(test_loader_set.dataset), kl_loss_all / len(test_loader_set.dataset)

# %%
# testing the model
total_test_losses = []
feature_test_losses = []
edge_test_losses = []
kl_test_losses = []
closs_test_losses=[]
for epoch in range(1,epochs+1):
    ttloss,tcdloss,tfloss,teloss,tklloss = test()
    print(f'Epoch: {epoch:03d}')
    print(f'Test Loss: {ttloss:.4f}, Chamfer Loss: {tcdloss:.4f}, Feature Loss: {tfloss:.4f}, Edge Loss: {teloss:.4f}, KL Loss: {tklloss:.4f}')
    total_test_losses.append(ttloss)
    feature_test_losses.append(tfloss)
    edge_test_losses.append(teloss)
    kl_test_losses.append(tklloss)
    closs_test_losses.append(tcdloss)
# Out:
# /tmp/ipykernel_3846/3236299723.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   closs=torch.tensor(closs, dtype=torch.float32)
# Epoch: 001
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 002
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 003
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 004
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 005
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 006
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 007
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 008
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 009
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 010
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 011
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 012
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 013
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 014
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 015
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 016
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 017
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 018
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 019
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 020
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 021
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 022
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 023
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 024
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 025
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 026
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 027
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 028
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 029
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 030
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 031
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 032
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 033
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 034
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 035
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 036
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 037
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 038
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 039
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 040
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 041
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 042
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 043
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 044
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 045
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 046
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 047
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 048
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 049
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 050
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 051
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 052
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 053
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 054
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 055
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 056
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 057
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 058
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 059
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 060
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 061
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 062
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 063
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 064
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 065
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 066
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 067
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 068
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 069
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 070
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 071
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 072
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 073
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 074
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 075
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 076
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 077
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 078
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 079
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 080
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 081
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 082
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 083
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 084
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 085
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 086
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 087
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 088
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 089
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 090
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 091
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 092
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 093
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 094
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 095
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 096
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 097
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 098
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 099
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765
# Epoch: 100
# Test Loss: 0.2533, Chamfer Loss: 0.1509, Feature Loss: 0.1024, Edge Loss: 0.0000, KL Loss: 0.0765

# %%
# plotting the losses
# Initial comparision between train and validation losses
plt.figure(figsize=(15,10))
plt.plot(total_train_losses, label='Train')
plt.plot(total_val_losses, label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('25k frames Train vs Validation Loss ')
plt.savefig('6.png')
plt.show()

# %%
# comparision between train and test losses
plt.figure(figsize=(15,10))
plt.plot(total_train_losses, label='Train')
plt.plot(total_test_losses, label='Test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('25k frames Train vs Test Loss ')
plt.savefig('7.png')
plt.show()

# %%
# validation vs test losses
plt.figure(figsize=(15,10))
plt.plot(total_val_losses, label='Validation')
plt.plot(total_test_losses, label='Test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('25k frames Validation vs Test Loss ')
plt.savefig('8.png')
plt.show()

# %%
# Chamfer Loss Comparision in all three cases
plt.figure(figsize=(15,10))
plt.plot(closs_train_losses, label='Train')
plt.plot(closs_val_losses, label='Validation')
plt.plot(closs_test_losses, label='Test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('25k frames Chamfer Loss Comparision')
plt.savefig('9.png')
plt.show()

# %%
# Feature Loss Comparision in all three cases
plt.figure(figsize=(15,10))
plt.plot(feature_train_losses, label='Train')
plt.plot(feature_val_losses, label='Validation')
plt.plot(feature_test_losses, label='Test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('25k frames Feature Loss Comparision')
plt.savefig('10.png')
plt.show()
