# %% [markdown]
# # To write function to chamfer distance

# %%
from IPython.display import Image
Image(filename='test.png')

# %%
def function():
# Out:
#   Cell In[3], line 1
#     def function():
#                    ^
# SyntaxError: incomplete input
