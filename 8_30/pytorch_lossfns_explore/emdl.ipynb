# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import torch
import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx

import numpy as np
import matplotlib.pyplot as plt
from PyEMD import EMD
import emd

# %%
emd=EMD()

# %%
all_frames = md.load_xtc("../../aug23/eql2.xtc", top="../../aug23/conf.gro")

# %%
all_frames_fatures = []

for i in range(all_frames.xyz.shape[0]):
    mol_com_pos = []

    for res in all_frames.top.residues:
        # print(res.index,end=" ")
        pos = []
        for atom in res.atoms:
            # print(atom.index,"-->" , frame.xyz[0][atom.index],end=" ")
            pos.append(all_frames.xyz[i][atom.index])
        mol_com_pos.append(np.mean(pos,axis=0))
        
        # print()
    mol_com_pos = np.array(mol_com_pos).astype(np.float32)  
    all_frames_fatures.append(mol_com_pos)

all_frames_fatures = np.array(all_frames_fatures).astype(np.float32)
print(all_frames_fatures.shape)
# Out:
# (51, 592, 3)

# %%
print(dir(all_frames.topology.residue(0)))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_atoms', 'atom', 'atoms', 'atoms_by_name', 'chain', 'code', 'index', 'is_nucleic', 'is_protein', 'is_water', 'n_atoms', 'name', 'resSeq', 'segment_id']

# %%
n_frames = all_frames.xyz.shape[0]
n_atoms = all_frames.topology.residue(0).n_atoms
n_mols = all_frames.topology.n_residues

# %%
print("number of molecules",n_mols)
print("number of atoms in molecule",n_atoms)
print("number of frames",n_frames)
# Out:
# number of molecules 592
# number of atoms in molecule 4
# number of frames 51

# %%
# %matplotlib widget

frame = 10

fig = plt.figure(figsize=(15,4))
ax1 = fig.add_subplot(projection='3d')
ax1.scatter(all_frames_fatures[frame][:,0],all_frames_fatures[frame][:,1],all_frames_fatures[frame][:,2])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index

# %%
cutoff = 0.5

all_edge_list = []
for frame_i in range(n_frames):
    from_list = []
    to_list = []

    for i in range(len(all_frames_fatures[frame_i])):
        for j in range(i+1,len(all_frames_fatures[frame_i])):
            if np.linalg.norm(all_frames_fatures[frame_i][i]-all_frames_fatures[frame_i][j]) < cutoff:
                # print(i,j,np.linalg.norm(mol_com_pos[i]-mol_com_pos[j]))
                from_list.append(i)
                to_list.append(j)

                to_list.append(i)
                from_list.append(j)

    edge_list = np.array([from_list,to_list]).astype(np.int64)
    all_edge_list.append(edge_list)

print(len(all_edge_list))
# Out:
# 51

# %%
# %matplotlib widget

frame = 10

plt.figure(figsize=(15,10))
adj_binary = convert_to_adj(all_edge_list[frame], num_nodes=592)
indices = torch.where(adj_binary)
G = nx.Graph()
edges = [(i, j) for i, j in zip(indices[0].tolist(), indices[1].tolist()) if i != j]
G.add_edges_from(edges)
nx.draw_networkx(G)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Converting to pytorch graph object

# %%
graphs = []
for frame in range(n_frames):
    g = data.Data(x=torch.tensor(all_frames_fatures[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
    graphs.append(g)

print(graphs[0])
# Out:
# Data(x=[592, 3], edge_index=[2, 7968], y=[1])

# %% [markdown]
# ## Model

# %%
from typing import Optional, Tuple

import torch
from torch import Tensor
from torch.nn import Module

from torch_geometric.nn.inits import reset
from torch_geometric.utils import negative_sampling

EPS = 1e-15
MAX_LOGSTD = 10
edgeShape = None
featureShape = None


class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""

    def forward(self, z: Tensor, edge_index: Tensor,
                sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value

    def forward_all(self, z: Tensor, sigmoid: bool = True) -> Tensor:
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj


class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (torch.nn.Module): The encoder module.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        reset(self.encoder)
        reset(self.decoder)

    def forward(self, *args, **kwargs) -> Tensor:  # pragma: no cover
        r"""Alias for :meth:`encode`."""
        return self.encoder(*args, **kwargs)

    def encode(self, *args, **kwargs) -> Tensor:
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)

    def decode(self, *args, **kwargs) -> Tensor:
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)

    def recon_loss(self, z: Tensor, pos_edge_index: Tensor,
                   neg_edge_index: Optional[Tensor] = None) -> Tensor:
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :obj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to train against.
            neg_edge_index (torch.Tensor, optional): The negative edges to
                train against. If not given, uses negative sampling to
                calculate negative edges. (default: :obj:`None`)
        """
        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True)[0] + EPS).mean()

        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index.long(), sigmoid=True)[0] +
                              EPS).mean()

        return pos_loss + neg_loss

    def test(self, z: Tensor, pos_edge_index: Tensor,
             neg_edge_index: Tensor) -> Tuple[Tensor, Tensor]:
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        
        scores.

        Args:
            z (torch.Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (torch.Tensor): The positive edges to evaluate
                against.
            neg_edge_index (torch.Tensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import average_precision_score, roc_auc_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)

        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)


class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (torch.nn.Module): The encoder module to compute :math:`\mu`
            and :math:`\log\sigma^2`.
        decoder (torch.nn.Module, optional): The decoder module. If set to
            :obj:`None`, will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """

    def __init__(self, encoder: Module, decoder: Optional[Module] = None):
        super().__init__(encoder, decoder)

    def reparametrize(self, mu: Tensor, logstd: Tensor) -> Tensor:
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs) -> Tensor:
        """"""
        self.__mu__, self.__logstd__, self.edge_index = self.encoder(
            *args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z, self.edge_index

    def kl_loss(self, mu: Optional[Tensor] = None,
                logstd: Optional[Tensor] = None) -> Tensor:
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (torch.Tensor, optional): The latent space for :math:`\mu`. If
                set to :obj:`None`, uses the last computation of :math:`\mu`.
                (default: :obj:`None`)
            logstd (torch.Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`. (default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
def norm_g(g):
    degrees = torch.sum(g, 1)
    g = g / degrees
    return g


def top_k_graph(scores, g, h, k):
    num_nodes = g.shape[0]
    values, idx = torch.topk(scores, max(2, int(k*num_nodes)))
    new_h = h[idx, :]
    values = torch.unsqueeze(values, -1)
    new_h = torch.mul(new_h, values)
    un_g = g.bool().float()
    un_g = torch.matmul(un_g, un_g).bool().float()
    un_g = un_g[idx, :]
    un_g = un_g[:, idx]
    g = norm_g(un_g)
    return g, new_h, idx

class Pool(torch.nn.Module):

    def __init__(self, k, in_dim, p):
        super(Pool, self).__init__()
        self.k = k
        self.sigmoid = torch.nn.Sigmoid()
        self.proj = torch.nn.Linear(in_dim, 1)
        self.drop = torch.nn.Dropout(p=p) if p > 0 else torch.nn.Identity()

    def forward(self, g, h):
        Z = self.drop(h)
        weights = self.proj(Z).squeeze()
        scores = self.sigmoid(weights)
        return top_k_graph(scores, g, h, self.k)


class Unpool(torch.nn.Module):

    def __init__(self, *args):
        super(Unpool, self).__init__()

    def forward(self, h, edge_indices,factor=1):
        # add zeros to h factor times
        global featureShape
        h = torch.cat([h, torch.zeros(max(featureShape[0]- h.shape[0],0), h.shape[1]).to(h.device)], dim=0)
        return h

class Unpool2(torch.nn.Module):
    def __init__(self, *args):
        super(Unpool2, self).__init__()

    def forward(self, batch, unpool_ratio):
        num_nodes = batch[-1].item() + 1
        expanded_batch = batch.unsqueeze(1).repeat(1, unpool_ratio)  # Repeat batch indices
        expanded_batch = expanded_batch.view(-1)  # Flatten the batch indices
        return  expanded_batch

# %%
import torch.nn.functional as F



class VariationalGCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2*out_channels, 1 * out_channels)
        self.conv_mu = GCNConv(1 * out_channels, out_channels)
        self.conv_logstd = GCNConv(1 * out_channels, out_channels)

    def forward(self, x, edge_index):
        global edgeShape, featureShape
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index), edge_index

# %%
class VariationalGCNDecoder(torch.nn.Module):
    def __init__(self,in_channels,out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels)
        self.conv2 = GCNConv(2 * out_channels, 1 * out_channels)
    def forward(self, x, edge_index, sigmoid=True):
        global edgeShape, featureShape
        # print("input:",x.shape, edge_index.shape)
        x = self.conv1(x, edge_index)
        x = F.silu(x)
        # print("conv1:",x.shape, edge_index.shape)
        x = self.conv2(x, edge_index)
        x = F.silu(x)
        # print("conv2:",x.shape, edge_index.shape)
        return x, edge_index

# %%
import os
in_channels = graphs[0].num_features
out_channels = 2
lr = 1e-4
n_epochs = 100
batch_size=2
force_train=True

model = VGAE(VariationalGCNEncoder(in_channels, out_channels),
            VariationalGCNDecoder(out_channels, in_channels))
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# train_loader = DataLoader(graphs, batch_size=batch_size)

# %%
from PyEMD import EMD
import emd
emd=EMD()

# %%
import torch
import torch.nn as nn

# import _emd_ext._emd as emd


class EMDFunction(torch.autograd.Function):
	@staticmethod
	def forward(self, xyz1, xyz2):
		cost, match = emd.emd_forward(xyz1, xyz2)
		self.save_for_backward(xyz1, xyz2, match)
		return cost


	@staticmethod
	def backward(self, grad_output):
		xyz1, xyz2, match = self.saved_tensors
		grad_xyz1, grad_xyz2 = emd.emd_backward(xyz1, xyz2, match)
		return grad_xyz1, grad_xyz2




class EMDLoss(nn.Module):
	'''
	Computes the (approximate) Earth Mover's Distance between two point sets. 

	IMPLEMENTATION LIMITATIONS:
	- Double tensors must have <=11 dimensions
	- Float tensors must have <=23 dimensions
	This is due to the use of CUDA shared memory in the computation. This shared memory is limited by the hardware to 48kB.
	'''

	def __init__(self):
		super(EMDLoss, self).__init__()

	def forward(self, xyz1, xyz2):

		assert xyz1.shape[-1] == xyz2.shape[-1], 'Both point sets must have the same dimensionality'
		if xyz1.dtype == torch.float64 and xyz1.shape[-1] > 11:
			error('Tensors of type double can have a maximum of 11 dimensions')
		if xyz1.dtype == torch.float32 and xyz1.shape[-1] > 23:
			error('Tensors of type float can have a maximum of 23 dimensions')

		return EMDFunction.apply(xyz1, xyz2)

# %% [markdown]
# dist=EMDLoss()
# p1 = torch.rand(1,5,3).cuda().double()
# p2 = torch.rand(1,10,3).cuda().double()
# p1.requires_grad = True
# p2.requires_grad = True
#
# cost = dist(p1, p2)
#
#
# print(cost)
# loss = torch.sum(cost)
# print(loss)
# loss.backward()
# print(p1.grad)
# print(p2.grad)

# %%
train_loader_set = DataLoader(graphs[:int(n_frames*0.6)], batch_size=batch_size, shuffle=True)
validation_loader_set = DataLoader(graphs[int(n_frames*0.6):int(n_frames*0.8)], batch_size=batch_size, shuffle=True)
test_loader_set = DataLoader(graphs[int(n_frames*0.8):], batch_size=batch_size, shuffle=True)

# %%
lossFxn = torch.nn.MSELoss()
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0

    for data in train_loader_set:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)

        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss
        loss = loss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)

        loss.backward()
        optimizer.step()

        

    return loss_all / len(train_loader_set.dataset), feature_loss_all / len(train_loader_set.dataset), edge_loss_all / len(train_loader_set.dataset), kl_loss_all / len(train_loader_set.dataset)

# %%
lossFxn = torch.nn.MSELoss()
def test():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in test_loader_set:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index= model.decode(z, encoded_edge_index)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        

    return loss_all / len(test_loader_set), feature_loss_all / len(test_loader_set), edge_loss_all / len(test_loader_set), kl_loss_all / len(test_loader_set)

# %%
lossFxn = torch.nn.MSELoss()
def validate():
    model.eval()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    type_loss_all = 0

    for data in validation_loader_set:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index= model.decode(z, encoded_edge_index)
        
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss 

        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        

    return loss_all / len(validation_loader_set), feature_loss_all / len(validation_loader_set), edge_loss_all / len(validation_loader_set), kl_loss_all / len(validation_loader_set)

# %%
total_losses = []
feature_losses = []
edge_losses = []
kl_losses = []
val_total_losses = []
val_feature_losses = []
val_edge_losses = []
val_kl_losses = []
test_total_losses = []
test_feature_losses = []
test_edge_losses = []
test_kl_losses = []
for epoch in range(1, n_epochs + 1):
    total_loss, feature_loss, edge_loss, kl_loss = train()
    val_total_loss, val_feature_loss, val_edge_loss, val_kl_loss = validate()
    test_total_loss, test_feature_loss, test_edge_loss, test_kl_loss = test()
    print(f'Epoch: {epoch:03d}')
    print(f'TRAIN : Total Loss: {total_loss:.4f}, Feature Loss: {feature_loss:.4f}, Edge Loss: {edge_loss:.4f}')
    print(f'VALIDATE : Total Loss: {val_total_loss:.4f}, Feature Loss: {val_feature_loss:.4f}, Edge Loss: {val_edge_loss:.4f}')
    print(f'TEST : Total Loss: {test_total_loss:.4f}, Feature Loss: {test_feature_loss:.4f}, Edge Loss: {test_edge_loss:.4f}')
    total_losses.append(total_loss)
    feature_losses.append(feature_loss)
    edge_losses.append(edge_loss)
    kl_losses.append(kl_loss)
    val_total_losses.append(val_total_loss)
    val_feature_losses.append(val_feature_loss)
    val_edge_losses.append(val_edge_loss)
    val_kl_losses.append(val_kl_loss)
    test_total_losses.append(test_total_loss)
    test_feature_losses.append(test_feature_loss)
    test_edge_losses.append(test_edge_loss)
    test_kl_losses.append(test_kl_loss)
# Out:
# Epoch: 001
# TRAIN : Total Loss: 1.1330, Feature Loss: 1.1330, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.2340, Feature Loss: 2.2340, Edge Loss: 0.0000
# TEST : Total Loss: 2.2566, Feature Loss: 2.2566, Edge Loss: 0.0000
# Epoch: 002
# TRAIN : Total Loss: 1.1290, Feature Loss: 1.1290, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.2254, Feature Loss: 2.2254, Edge Loss: 0.0000
# TEST : Total Loss: 2.2491, Feature Loss: 2.2491, Edge Loss: 0.0000
# Epoch: 003
# TRAIN : Total Loss: 1.1237, Feature Loss: 1.1237, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.2167, Feature Loss: 2.2167, Edge Loss: 0.0000
# TEST : Total Loss: 2.2388, Feature Loss: 2.2388, Edge Loss: 0.0000
# Epoch: 004
# TRAIN : Total Loss: 1.1185, Feature Loss: 1.1185, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.2080, Feature Loss: 2.2080, Edge Loss: 0.0000
# TEST : Total Loss: 2.2284, Feature Loss: 2.2284, Edge Loss: 0.0000
# Epoch: 005
# TRAIN : Total Loss: 1.1154, Feature Loss: 1.1154, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1993, Feature Loss: 2.1993, Edge Loss: 0.0000
# TEST : Total Loss: 2.2217, Feature Loss: 2.2217, Edge Loss: 0.0000
# Epoch: 006
# TRAIN : Total Loss: 1.1110, Feature Loss: 1.1110, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1905, Feature Loss: 2.1905, Edge Loss: 0.0000
# TEST : Total Loss: 2.2165, Feature Loss: 2.2165, Edge Loss: 0.0000
# Epoch: 007
# TRAIN : Total Loss: 1.1014, Feature Loss: 1.1014, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1817, Feature Loss: 2.1817, Edge Loss: 0.0000
# TEST : Total Loss: 2.2040, Feature Loss: 2.2040, Edge Loss: 0.0000
# Epoch: 008
# TRAIN : Total Loss: 1.1001, Feature Loss: 1.1001, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1728, Feature Loss: 2.1728, Edge Loss: 0.0000
# TEST : Total Loss: 2.1986, Feature Loss: 2.1986, Edge Loss: 0.0000
# Epoch: 009
# TRAIN : Total Loss: 1.0941, Feature Loss: 1.0941, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1637, Feature Loss: 2.1637, Edge Loss: 0.0000
# TEST : Total Loss: 2.1851, Feature Loss: 2.1851, Edge Loss: 0.0000
# Epoch: 010
# TRAIN : Total Loss: 1.0935, Feature Loss: 1.0935, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1546, Feature Loss: 2.1546, Edge Loss: 0.0000
# TEST : Total Loss: 2.1838, Feature Loss: 2.1838, Edge Loss: 0.0000
# Epoch: 011
# TRAIN : Total Loss: 1.0864, Feature Loss: 1.0864, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1454, Feature Loss: 2.1454, Edge Loss: 0.0000
# TEST : Total Loss: 2.1670, Feature Loss: 2.1670, Edge Loss: 0.0000
# Epoch: 012
# TRAIN : Total Loss: 1.0818, Feature Loss: 1.0818, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1361, Feature Loss: 2.1361, Edge Loss: 0.0000
# TEST : Total Loss: 2.1616, Feature Loss: 2.1616, Edge Loss: 0.0000
# Epoch: 013
# TRAIN : Total Loss: 1.0773, Feature Loss: 1.0773, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1266, Feature Loss: 2.1266, Edge Loss: 0.0000
# TEST : Total Loss: 2.1474, Feature Loss: 2.1474, Edge Loss: 0.0000
# Epoch: 014
# TRAIN : Total Loss: 1.0752, Feature Loss: 1.0752, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1170, Feature Loss: 2.1170, Edge Loss: 0.0000
# TEST : Total Loss: 2.1396, Feature Loss: 2.1396, Edge Loss: 0.0000
# Epoch: 015
# TRAIN : Total Loss: 1.0681, Feature Loss: 1.0681, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.1073, Feature Loss: 2.1073, Edge Loss: 0.0000
# TEST : Total Loss: 2.1283, Feature Loss: 2.1283, Edge Loss: 0.0000
# Epoch: 016
# TRAIN : Total Loss: 1.0608, Feature Loss: 1.0608, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0974, Feature Loss: 2.0974, Edge Loss: 0.0000
# TEST : Total Loss: 2.1184, Feature Loss: 2.1184, Edge Loss: 0.0000
# Epoch: 017
# TRAIN : Total Loss: 1.0565, Feature Loss: 1.0565, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0874, Feature Loss: 2.0874, Edge Loss: 0.0000
# TEST : Total Loss: 2.1082, Feature Loss: 2.1082, Edge Loss: 0.0000
# Epoch: 018
# TRAIN : Total Loss: 1.0524, Feature Loss: 1.0524, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0772, Feature Loss: 2.0772, Edge Loss: 0.0000
# TEST : Total Loss: 2.0980, Feature Loss: 2.0980, Edge Loss: 0.0000
# Epoch: 019
# TRAIN : Total Loss: 1.0482, Feature Loss: 1.0482, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0669, Feature Loss: 2.0669, Edge Loss: 0.0000
# TEST : Total Loss: 2.0891, Feature Loss: 2.0891, Edge Loss: 0.0000
# Epoch: 020
# TRAIN : Total Loss: 1.0439, Feature Loss: 1.0439, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0565, Feature Loss: 2.0565, Edge Loss: 0.0000
# TEST : Total Loss: 2.0768, Feature Loss: 2.0768, Edge Loss: 0.0000
# Epoch: 021
# TRAIN : Total Loss: 1.0387, Feature Loss: 1.0387, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0459, Feature Loss: 2.0459, Edge Loss: 0.0000
# TEST : Total Loss: 2.0680, Feature Loss: 2.0680, Edge Loss: 0.0000
# Epoch: 022
# TRAIN : Total Loss: 1.0311, Feature Loss: 1.0311, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0352, Feature Loss: 2.0352, Edge Loss: 0.0000
# TEST : Total Loss: 2.0554, Feature Loss: 2.0554, Edge Loss: 0.0000
# Epoch: 023
# TRAIN : Total Loss: 1.0281, Feature Loss: 1.0281, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0244, Feature Loss: 2.0244, Edge Loss: 0.0000
# TEST : Total Loss: 2.0491, Feature Loss: 2.0491, Edge Loss: 0.0000
# Epoch: 024
# TRAIN : Total Loss: 1.0200, Feature Loss: 1.0200, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0134, Feature Loss: 2.0134, Edge Loss: 0.0000
# TEST : Total Loss: 2.0413, Feature Loss: 2.0413, Edge Loss: 0.0000
# Epoch: 025
# TRAIN : Total Loss: 1.0169, Feature Loss: 1.0169, Edge Loss: 0.0000
# VALIDATE : Total Loss: 2.0023, Feature Loss: 2.0023, Edge Loss: 0.0000
# TEST : Total Loss: 2.0233, Feature Loss: 2.0233, Edge Loss: 0.0000
# Epoch: 026
# TRAIN : Total Loss: 1.0113, Feature Loss: 1.0113, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.9911, Feature Loss: 1.9911, Edge Loss: 0.0000
# TEST : Total Loss: 2.0110, Feature Loss: 2.0110, Edge Loss: 0.0000
# Epoch: 027
# TRAIN : Total Loss: 1.0021, Feature Loss: 1.0021, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.9798, Feature Loss: 1.9798, Edge Loss: 0.0000
# TEST : Total Loss: 2.0019, Feature Loss: 2.0019, Edge Loss: 0.0000
# Epoch: 028
# TRAIN : Total Loss: 1.0026, Feature Loss: 1.0026, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.9684, Feature Loss: 1.9684, Edge Loss: 0.0000
# TEST : Total Loss: 1.9901, Feature Loss: 1.9901, Edge Loss: 0.0000
# Epoch: 029
# TRAIN : Total Loss: 0.9934, Feature Loss: 0.9934, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.9568, Feature Loss: 1.9568, Edge Loss: 0.0000
# TEST : Total Loss: 1.9810, Feature Loss: 1.9810, Edge Loss: 0.0000
# Epoch: 030
# TRAIN : Total Loss: 0.9893, Feature Loss: 0.9893, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.9451, Feature Loss: 1.9451, Edge Loss: 0.0000
# TEST : Total Loss: 1.9648, Feature Loss: 1.9648, Edge Loss: 0.0000
# Epoch: 031
# TRAIN : Total Loss: 0.9821, Feature Loss: 0.9821, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.9334, Feature Loss: 1.9334, Edge Loss: 0.0000
# TEST : Total Loss: 1.9529, Feature Loss: 1.9529, Edge Loss: 0.0000
# Epoch: 032
# TRAIN : Total Loss: 0.9768, Feature Loss: 0.9768, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.9215, Feature Loss: 1.9215, Edge Loss: 0.0000
# TEST : Total Loss: 1.9432, Feature Loss: 1.9432, Edge Loss: 0.0000
# Epoch: 033
# TRAIN : Total Loss: 0.9713, Feature Loss: 0.9713, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.9095, Feature Loss: 1.9095, Edge Loss: 0.0000
# TEST : Total Loss: 1.9306, Feature Loss: 1.9306, Edge Loss: 0.0000
# Epoch: 034
# TRAIN : Total Loss: 0.9616, Feature Loss: 0.9616, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.8974, Feature Loss: 1.8974, Edge Loss: 0.0000
# TEST : Total Loss: 1.9157, Feature Loss: 1.9157, Edge Loss: 0.0000
# Epoch: 035
# TRAIN : Total Loss: 0.9596, Feature Loss: 0.9596, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.8852, Feature Loss: 1.8852, Edge Loss: 0.0000
# TEST : Total Loss: 1.9051, Feature Loss: 1.9051, Edge Loss: 0.0000
# Epoch: 036
# TRAIN : Total Loss: 0.9540, Feature Loss: 0.9540, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.8729, Feature Loss: 1.8729, Edge Loss: 0.0000
# TEST : Total Loss: 1.8927, Feature Loss: 1.8927, Edge Loss: 0.0000
# Epoch: 037
# TRAIN : Total Loss: 0.9427, Feature Loss: 0.9427, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.8604, Feature Loss: 1.8604, Edge Loss: 0.0000
# TEST : Total Loss: 1.8804, Feature Loss: 1.8804, Edge Loss: 0.0000
# Epoch: 038
# TRAIN : Total Loss: 0.9423, Feature Loss: 0.9423, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.8479, Feature Loss: 1.8479, Edge Loss: 0.0000
# TEST : Total Loss: 1.8691, Feature Loss: 1.8691, Edge Loss: 0.0000
# Epoch: 039
# TRAIN : Total Loss: 0.9348, Feature Loss: 0.9348, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.8354, Feature Loss: 1.8354, Edge Loss: 0.0000
# TEST : Total Loss: 1.8562, Feature Loss: 1.8562, Edge Loss: 0.0000
# Epoch: 040
# TRAIN : Total Loss: 0.9273, Feature Loss: 0.9273, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.8227, Feature Loss: 1.8227, Edge Loss: 0.0000
# TEST : Total Loss: 1.8489, Feature Loss: 1.8489, Edge Loss: 0.0000
# Epoch: 041
# TRAIN : Total Loss: 0.9206, Feature Loss: 0.9206, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.8099, Feature Loss: 1.8099, Edge Loss: 0.0000
# TEST : Total Loss: 1.8308, Feature Loss: 1.8308, Edge Loss: 0.0000
# Epoch: 042
# TRAIN : Total Loss: 0.9166, Feature Loss: 0.9166, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.7970, Feature Loss: 1.7970, Edge Loss: 0.0000
# TEST : Total Loss: 1.8163, Feature Loss: 1.8163, Edge Loss: 0.0000
# Epoch: 043
# TRAIN : Total Loss: 0.9088, Feature Loss: 0.9088, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.7841, Feature Loss: 1.7841, Edge Loss: 0.0000
# TEST : Total Loss: 1.8045, Feature Loss: 1.8045, Edge Loss: 0.0000
# Epoch: 044
# TRAIN : Total Loss: 0.8996, Feature Loss: 0.8996, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.7710, Feature Loss: 1.7710, Edge Loss: 0.0000
# TEST : Total Loss: 1.7917, Feature Loss: 1.7917, Edge Loss: 0.0000
# Epoch: 045
# TRAIN : Total Loss: 0.8935, Feature Loss: 0.8935, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.7578, Feature Loss: 1.7578, Edge Loss: 0.0000
# TEST : Total Loss: 1.7779, Feature Loss: 1.7779, Edge Loss: 0.0000
# Epoch: 046
# TRAIN : Total Loss: 0.8873, Feature Loss: 0.8873, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.7446, Feature Loss: 1.7446, Edge Loss: 0.0000
# TEST : Total Loss: 1.7651, Feature Loss: 1.7651, Edge Loss: 0.0000
# Epoch: 047
# TRAIN : Total Loss: 0.8805, Feature Loss: 0.8805, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.7313, Feature Loss: 1.7313, Edge Loss: 0.0000
# TEST : Total Loss: 1.7517, Feature Loss: 1.7517, Edge Loss: 0.0000
# Epoch: 048
# TRAIN : Total Loss: 0.8763, Feature Loss: 0.8763, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.7179, Feature Loss: 1.7179, Edge Loss: 0.0000
# TEST : Total Loss: 1.7380, Feature Loss: 1.7380, Edge Loss: 0.0000
# Epoch: 049
# TRAIN : Total Loss: 0.8695, Feature Loss: 0.8695, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.7045, Feature Loss: 1.7045, Edge Loss: 0.0000
# TEST : Total Loss: 1.7269, Feature Loss: 1.7269, Edge Loss: 0.0000
# Epoch: 050
# TRAIN : Total Loss: 0.8603, Feature Loss: 0.8603, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.6910, Feature Loss: 1.6910, Edge Loss: 0.0000
# TEST : Total Loss: 1.7162, Feature Loss: 1.7162, Edge Loss: 0.0000
# Epoch: 051
# TRAIN : Total Loss: 0.8529, Feature Loss: 0.8529, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.6775, Feature Loss: 1.6775, Edge Loss: 0.0000
# TEST : Total Loss: 1.6996, Feature Loss: 1.6996, Edge Loss: 0.0000
# Epoch: 052
# TRAIN : Total Loss: 0.8466, Feature Loss: 0.8466, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.6638, Feature Loss: 1.6638, Edge Loss: 0.0000
# TEST : Total Loss: 1.6825, Feature Loss: 1.6825, Edge Loss: 0.0000
# Epoch: 053
# TRAIN : Total Loss: 0.8448, Feature Loss: 0.8448, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.6502, Feature Loss: 1.6502, Edge Loss: 0.0000
# TEST : Total Loss: 1.6721, Feature Loss: 1.6721, Edge Loss: 0.0000
# Epoch: 054
# TRAIN : Total Loss: 0.8330, Feature Loss: 0.8330, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.6364, Feature Loss: 1.6364, Edge Loss: 0.0000
# TEST : Total Loss: 1.6549, Feature Loss: 1.6549, Edge Loss: 0.0000
# Epoch: 055
# TRAIN : Total Loss: 0.8269, Feature Loss: 0.8269, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.6227, Feature Loss: 1.6227, Edge Loss: 0.0000
# TEST : Total Loss: 1.6410, Feature Loss: 1.6410, Edge Loss: 0.0000
# Epoch: 056
# TRAIN : Total Loss: 0.8204, Feature Loss: 0.8204, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.6088, Feature Loss: 1.6088, Edge Loss: 0.0000
# TEST : Total Loss: 1.6332, Feature Loss: 1.6332, Edge Loss: 0.0000
# Epoch: 057
# TRAIN : Total Loss: 0.8126, Feature Loss: 0.8126, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.5950, Feature Loss: 1.5950, Edge Loss: 0.0000
# TEST : Total Loss: 1.6124, Feature Loss: 1.6124, Edge Loss: 0.0000
# Epoch: 058
# TRAIN : Total Loss: 0.8050, Feature Loss: 0.8050, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.5811, Feature Loss: 1.5811, Edge Loss: 0.0000
# TEST : Total Loss: 1.5991, Feature Loss: 1.5991, Edge Loss: 0.0000
# Epoch: 059
# TRAIN : Total Loss: 0.7992, Feature Loss: 0.7992, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.5671, Feature Loss: 1.5671, Edge Loss: 0.0000
# TEST : Total Loss: 1.5864, Feature Loss: 1.5864, Edge Loss: 0.0000
# Epoch: 060
# TRAIN : Total Loss: 0.7893, Feature Loss: 0.7893, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.5532, Feature Loss: 1.5532, Edge Loss: 0.0000
# TEST : Total Loss: 1.5704, Feature Loss: 1.5704, Edge Loss: 0.0000
# Epoch: 061
# TRAIN : Total Loss: 0.7874, Feature Loss: 0.7874, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.5392, Feature Loss: 1.5392, Edge Loss: 0.0000
# TEST : Total Loss: 1.5570, Feature Loss: 1.5570, Edge Loss: 0.0000
# Epoch: 062
# TRAIN : Total Loss: 0.7833, Feature Loss: 0.7833, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.5253, Feature Loss: 1.5253, Edge Loss: 0.0000
# TEST : Total Loss: 1.5412, Feature Loss: 1.5412, Edge Loss: 0.0000
# Epoch: 063
# TRAIN : Total Loss: 0.7723, Feature Loss: 0.7723, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.5113, Feature Loss: 1.5113, Edge Loss: 0.0000
# TEST : Total Loss: 1.5282, Feature Loss: 1.5282, Edge Loss: 0.0000
# Epoch: 064
# TRAIN : Total Loss: 0.7666, Feature Loss: 0.7666, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.4974, Feature Loss: 1.4974, Edge Loss: 0.0000
# TEST : Total Loss: 1.5161, Feature Loss: 1.5161, Edge Loss: 0.0000
# Epoch: 065
# TRAIN : Total Loss: 0.7587, Feature Loss: 0.7587, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.4834, Feature Loss: 1.4834, Edge Loss: 0.0000
# TEST : Total Loss: 1.5006, Feature Loss: 1.5006, Edge Loss: 0.0000
# Epoch: 066
# TRAIN : Total Loss: 0.7481, Feature Loss: 0.7481, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.4694, Feature Loss: 1.4694, Edge Loss: 0.0000
# TEST : Total Loss: 1.4925, Feature Loss: 1.4925, Edge Loss: 0.0000
# Epoch: 067
# TRAIN : Total Loss: 0.7450, Feature Loss: 0.7450, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.4554, Feature Loss: 1.4554, Edge Loss: 0.0000
# TEST : Total Loss: 1.4758, Feature Loss: 1.4758, Edge Loss: 0.0000
# Epoch: 068
# TRAIN : Total Loss: 0.7369, Feature Loss: 0.7369, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.4415, Feature Loss: 1.4415, Edge Loss: 0.0000
# TEST : Total Loss: 1.4592, Feature Loss: 1.4592, Edge Loss: 0.0000
# Epoch: 069
# TRAIN : Total Loss: 0.7295, Feature Loss: 0.7295, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.4275, Feature Loss: 1.4275, Edge Loss: 0.0000
# TEST : Total Loss: 1.4502, Feature Loss: 1.4502, Edge Loss: 0.0000
# Epoch: 070
# TRAIN : Total Loss: 0.7223, Feature Loss: 0.7223, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.4136, Feature Loss: 1.4136, Edge Loss: 0.0000
# TEST : Total Loss: 1.4317, Feature Loss: 1.4317, Edge Loss: 0.0000
# Epoch: 071
# TRAIN : Total Loss: 0.7135, Feature Loss: 0.7135, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.3997, Feature Loss: 1.3997, Edge Loss: 0.0000
# TEST : Total Loss: 1.4158, Feature Loss: 1.4158, Edge Loss: 0.0000
# Epoch: 072
# TRAIN : Total Loss: 0.7114, Feature Loss: 0.7114, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.3858, Feature Loss: 1.3858, Edge Loss: 0.0000
# TEST : Total Loss: 1.4023, Feature Loss: 1.4023, Edge Loss: 0.0000
# Epoch: 073
# TRAIN : Total Loss: 0.7024, Feature Loss: 0.7024, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.3721, Feature Loss: 1.3721, Edge Loss: 0.0000
# TEST : Total Loss: 1.3885, Feature Loss: 1.3885, Edge Loss: 0.0000
# Epoch: 074
# TRAIN : Total Loss: 0.6950, Feature Loss: 0.6950, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.3583, Feature Loss: 1.3583, Edge Loss: 0.0000
# TEST : Total Loss: 1.3741, Feature Loss: 1.3741, Edge Loss: 0.0000
# Epoch: 075
# TRAIN : Total Loss: 0.6865, Feature Loss: 0.6865, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.3446, Feature Loss: 1.3446, Edge Loss: 0.0000
# TEST : Total Loss: 1.3641, Feature Loss: 1.3641, Edge Loss: 0.0000
# Epoch: 076
# TRAIN : Total Loss: 0.6809, Feature Loss: 0.6809, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.3310, Feature Loss: 1.3310, Edge Loss: 0.0000
# TEST : Total Loss: 1.3485, Feature Loss: 1.3485, Edge Loss: 0.0000
# Epoch: 077
# TRAIN : Total Loss: 0.6761, Feature Loss: 0.6761, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.3175, Feature Loss: 1.3175, Edge Loss: 0.0000
# TEST : Total Loss: 1.3329, Feature Loss: 1.3329, Edge Loss: 0.0000
# Epoch: 078
# TRAIN : Total Loss: 0.6658, Feature Loss: 0.6658, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.3040, Feature Loss: 1.3040, Edge Loss: 0.0000
# TEST : Total Loss: 1.3230, Feature Loss: 1.3230, Edge Loss: 0.0000
# Epoch: 079
# TRAIN : Total Loss: 0.6600, Feature Loss: 0.6600, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.2906, Feature Loss: 1.2906, Edge Loss: 0.0000
# TEST : Total Loss: 1.3058, Feature Loss: 1.3058, Edge Loss: 0.0000
# Epoch: 080
# TRAIN : Total Loss: 0.6550, Feature Loss: 0.6550, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.2772, Feature Loss: 1.2772, Edge Loss: 0.0000
# TEST : Total Loss: 1.2924, Feature Loss: 1.2924, Edge Loss: 0.0000
# Epoch: 081
# TRAIN : Total Loss: 0.6452, Feature Loss: 0.6452, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.2639, Feature Loss: 1.2639, Edge Loss: 0.0000
# TEST : Total Loss: 1.2794, Feature Loss: 1.2794, Edge Loss: 0.0000
# Epoch: 082
# TRAIN : Total Loss: 0.6417, Feature Loss: 0.6417, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.2508, Feature Loss: 1.2508, Edge Loss: 0.0000
# TEST : Total Loss: 1.2646, Feature Loss: 1.2646, Edge Loss: 0.0000
# Epoch: 083
# TRAIN : Total Loss: 0.6351, Feature Loss: 0.6351, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.2377, Feature Loss: 1.2377, Edge Loss: 0.0000
# TEST : Total Loss: 1.2543, Feature Loss: 1.2543, Edge Loss: 0.0000
# Epoch: 084
# TRAIN : Total Loss: 0.6280, Feature Loss: 0.6280, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.2247, Feature Loss: 1.2247, Edge Loss: 0.0000
# TEST : Total Loss: 1.2393, Feature Loss: 1.2393, Edge Loss: 0.0000
# Epoch: 085
# TRAIN : Total Loss: 0.6192, Feature Loss: 0.6192, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.2118, Feature Loss: 1.2118, Edge Loss: 0.0000
# TEST : Total Loss: 1.2322, Feature Loss: 1.2322, Edge Loss: 0.0000
# Epoch: 086
# TRAIN : Total Loss: 0.6110, Feature Loss: 0.6110, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1990, Feature Loss: 1.1990, Edge Loss: 0.0000
# TEST : Total Loss: 1.2192, Feature Loss: 1.2192, Edge Loss: 0.0000
# Epoch: 087
# TRAIN : Total Loss: 0.6057, Feature Loss: 0.6057, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1863, Feature Loss: 1.1863, Edge Loss: 0.0000
# TEST : Total Loss: 1.2042, Feature Loss: 1.2042, Edge Loss: 0.0000
# Epoch: 088
# TRAIN : Total Loss: 0.6063, Feature Loss: 0.6063, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1737, Feature Loss: 1.1737, Edge Loss: 0.0000
# TEST : Total Loss: 1.1937, Feature Loss: 1.1937, Edge Loss: 0.0000
# Epoch: 089
# TRAIN : Total Loss: 0.5963, Feature Loss: 0.5963, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1612, Feature Loss: 1.1612, Edge Loss: 0.0000
# TEST : Total Loss: 1.1758, Feature Loss: 1.1758, Edge Loss: 0.0000
# Epoch: 090
# TRAIN : Total Loss: 0.5878, Feature Loss: 0.5878, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1489, Feature Loss: 1.1489, Edge Loss: 0.0000
# TEST : Total Loss: 1.1618, Feature Loss: 1.1618, Edge Loss: 0.0000
# Epoch: 091
# TRAIN : Total Loss: 0.5844, Feature Loss: 0.5844, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1368, Feature Loss: 1.1368, Edge Loss: 0.0000
# TEST : Total Loss: 1.1524, Feature Loss: 1.1524, Edge Loss: 0.0000
# Epoch: 092
# TRAIN : Total Loss: 0.5774, Feature Loss: 0.5774, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1247, Feature Loss: 1.1247, Edge Loss: 0.0000
# TEST : Total Loss: 1.1400, Feature Loss: 1.1400, Edge Loss: 0.0000
# Epoch: 093
# TRAIN : Total Loss: 0.5733, Feature Loss: 0.5733, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1127, Feature Loss: 1.1127, Edge Loss: 0.0000
# TEST : Total Loss: 1.1265, Feature Loss: 1.1265, Edge Loss: 0.0000
# Epoch: 094
# TRAIN : Total Loss: 0.5630, Feature Loss: 0.5630, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.1009, Feature Loss: 1.1009, Edge Loss: 0.0000
# TEST : Total Loss: 1.1148, Feature Loss: 1.1148, Edge Loss: 0.0000
# Epoch: 095
# TRAIN : Total Loss: 0.5572, Feature Loss: 0.5572, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.0892, Feature Loss: 1.0892, Edge Loss: 0.0000
# TEST : Total Loss: 1.1030, Feature Loss: 1.1030, Edge Loss: 0.0000
# Epoch: 096
# TRAIN : Total Loss: 0.5541, Feature Loss: 0.5541, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.0777, Feature Loss: 1.0777, Edge Loss: 0.0000
# TEST : Total Loss: 1.0913, Feature Loss: 1.0913, Edge Loss: 0.0000
# Epoch: 097
# TRAIN : Total Loss: 0.5498, Feature Loss: 0.5498, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.0663, Feature Loss: 1.0663, Edge Loss: 0.0000
# TEST : Total Loss: 1.0784, Feature Loss: 1.0784, Edge Loss: 0.0000
# Epoch: 098
# TRAIN : Total Loss: 0.5392, Feature Loss: 0.5392, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.0551, Feature Loss: 1.0551, Edge Loss: 0.0000
# TEST : Total Loss: 1.0699, Feature Loss: 1.0699, Edge Loss: 0.0000
# Epoch: 099
# TRAIN : Total Loss: 0.5367, Feature Loss: 0.5367, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.0440, Feature Loss: 1.0440, Edge Loss: 0.0000
# TEST : Total Loss: 1.0558, Feature Loss: 1.0558, Edge Loss: 0.0000
# Epoch: 100
# TRAIN : Total Loss: 0.5312, Feature Loss: 0.5312, Edge Loss: 0.0000
# VALIDATE : Total Loss: 1.0330, Feature Loss: 1.0330, Edge Loss: 0.0000
# TEST : Total Loss: 1.0476, Feature Loss: 1.0476, Edge Loss: 0.0000

# %% [markdown]
# plt.figure(figsize=(14, 5))
# plt.plot(total_losses, label='Total Loss')
# plt.legend()
# plt.title('Total Loss')
# plt.show()

# %% [markdown]
# plt.figure(figsize=(14, 5))
# plt.plot(feature_losses, label='Feature Loss')
# plt.legend()
# plt.title('Feature Loss')
# plt.show()

# %%
plt.figure(figsize=(14, 5))
plt.plot(total_losses, label='train Loss')
plt.plot(test_total_losses, label='test loss')
plt.plot(val_total_losses, label='validate loss')
plt.legend()
plt.title('Total Loss')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(14, 5))
plt.plot(feature_losses, label='Feature Loss')
plt.legend()
plt.title('Feature Loss')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
train_loader = DataLoader(graphs, batch_size=1)

# %%
decoded_data=[]
for data in train_loader:
    model.eval()
    z,encoded_edge_index = model.encode(data.x, data.edge_index)
    decoded_data.append(z.detach().numpy())

decoded_data = np.array(decoded_data)

# %%
decoded_data.shape
# Out:
# (51, 592, 2)

# %%
frame = 49
plt.figure(figsize=(14, 5))
data = decoded_data[frame]
plt.scatter(data[:,0], data[:,1])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def earth_mover_distance(y_true, y_pred):
    return torch.mean(torch.square(torch.cumsum(y_true, dim=-1) - torch.cumsum(y_pred, dim=-1)), dim=-1)

# %%
lossFxn = torch.nn.MSELoss()
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    emd_loss_all=0
    for data in train_loader_set:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)
        emdloss=earth_mover_distance(decoded_x,data.x)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        loss = FeatureLoss + EdgeLoss + emdloss
        loss = loss 
        emd_loss_all+=float(emdloss)
        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)

        loss.backward()
        optimizer.step()

        

    return loss_all / len(train_loader_set.dataset), emd_loss_all/len(train_loader_set.dataset),feature_loss_all / len(train_loader_set.dataset), edge_loss_all / len(train_loader_set.dataset), kl_loss_all / len(train_loader_set.dataset)

# %%
total_losses = []
emd_losses=[]
feature_losses = []
edge_losses = []
kl_losses = []
for epoch in range(1, n_epochs + 1):
    total_loss, emd_loss, feature_loss, edge_loss, kl_loss = train()
    print(f'Epoch: {epoch:03d}')
    print(f'TRAIN : Total Loss: {total_loss:.4f},EMD Loss: {emd_loss:.4f}, Feature Loss: {feature_loss:.4f}, Edge Loss: {edge_loss:.4f}')
    total_losses.append(total_loss)
    emd_losses.append(emd_loss)
    feature_losses.append(feature_loss)
    edge_losses.append(edge_loss)
    kl_losses.append(kl_loss)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 7
#       5 kl_losses = []
#       6 for epoch in range(1, n_epochs + 1):
# ----> 7     total_loss, emd_loss, feature_loss, edge_loss, kl_loss = train()
#       8     print(f'Epoch: {epoch:03d}')
#       9     print(f'TRAIN : Total Loss: {total_loss:.4f},EMD Loss: {emd_loss:.4f}, Feature Loss: {feature_loss:.4f}, Edge Loss: {edge_loss:.4f}')
#
# Cell In[40], line 20, in train()
#      18 loss = FeatureLoss + EdgeLoss + emdloss
#      19 loss = loss
# ---> 20 emd_loss_all+=float(emdloss)
#      21 loss_all +=  float(loss)
#      22 feature_loss_all += float(FeatureLoss)
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
import time
import numpy as np
import torch
from torch import nn
from torch.autograd import Function
import emd




class emdFunction(Function):
    @staticmethod
    def forward(ctx, xyz1, xyz2, eps, iters):

        batchsize, n, _ = xyz1.size()
        _, m, _ = xyz2.size()

        assert(n == m)
        assert(xyz1.size()[0] == xyz2.size()[0])
        assert(n % 1024 == 0)
        assert(batchsize <= 512)

        xyz1 = xyz1.contiguous().float().cuda()
        xyz2 = xyz2.contiguous().float().cuda()
        dist = torch.zeros(batchsize, n, device='cuda').contiguous()
        assignment = torch.zeros(batchsize, n, device='cuda', dtype=torch.int32).contiguous() - 1
        assignment_inv = torch.zeros(batchsize, m, device='cuda', dtype=torch.int32).contiguous() - 1
        price = torch.zeros(batchsize, m, device='cuda').contiguous()
        bid = torch.zeros(batchsize, n, device='cuda', dtype=torch.int32).contiguous()
        bid_increments = torch.zeros(batchsize, n, device='cuda').contiguous()
        max_increments = torch.zeros(batchsize, m, device='cuda').contiguous()
        unass_idx = torch.zeros(batchsize * n, device='cuda', dtype=torch.int32).contiguous()
        max_idx = torch.zeros(batchsize * m, device='cuda', dtype=torch.int32).contiguous()
        unass_cnt = torch.zeros(512, dtype=torch.int32, device='cuda').contiguous()
        unass_cnt_sum = torch.zeros(512, dtype=torch.int32, device='cuda').contiguous()
        cnt_tmp = torch.zeros(512, dtype=torch.int32, device='cuda').contiguous()

        emd.forward(xyz1, xyz2, dist, assignment, price, assignment_inv, bid, bid_increments, max_increments, unass_idx, unass_cnt, unass_cnt_sum, cnt_tmp, max_idx, eps, iters)

        ctx.save_for_backward(xyz1, xyz2, assignment)
        return dist, assignment

    @staticmethod
    def backward(ctx, graddist, gradidx):
        xyz1, xyz2, assignment = ctx.saved_tensors
        graddist = graddist.contiguous()

        gradxyz1 = torch.zeros(xyz1.size(), device='cuda').contiguous()
        gradxyz2 = torch.zeros(xyz2.size(), device='cuda').contiguous()

        emd.backward(xyz1, xyz2, gradxyz1, graddist, assignment)
        return gradxyz1, gradxyz2, None, None

class emdModule(nn.Module):
    def __init__(self):
        super(emdModule, self).__init__()

    def forward(self, input1, input2, eps, iters):
        return emdFunction.apply(input1, input2, eps, iters)

def test_emd():
    x1 = torch.rand(20, 8192, 3).cuda() # please normalize your point cloud to [0, 1]
    x2 = torch.rand(20, 8192, 3).cuda()
    emd = emdModule()
    start_time = time.perf_counter()
    dis, assigment = emd(x1, x2, 0.002, 10000) # 0.005, 50 for training 
    print("Input_size: ", x1.shape)
    print("Runtime: %lfs" % (time.perf_counter() - start_time))
    print("EMD: %lf" % np.sqrt(dis.cpu()).mean())
    print("|set(assignment)|: %d" % assigment.unique().numel())
    assigment = assigment.cpu().numpy()
    assigment = np.expand_dims(assigment, -1)
    x2 = np.take_along_axis(x2, assigment, axis = 1)
    d = (x1 - x2) * (x1 - x2)
    print("Verified EMD: %lf" % np.sqrt(d.cpu().sum(-1)).mean())

test_emd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 77
#      74     d = (x1 - x2) * (x1 - x2)
#      75     print("Verified EMD: %lf" % np.sqrt(d.cpu().sum(-1)).mean())
# ---> 77 test_emd()
#
# Cell In[46], line 66, in test_emd()
#      64 emd = emdModule()
#      65 start_time = time.perf_counter()
# ---> 66 dis, assigment = emd(x1, x2, 0.002, 10000) # 0.005, 50 for training
#      67 print("Input_size: ", x1.shape)
#      68 print("Runtime: %lfs" % (time.perf_counter() - start_time))
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[46], line 59, in emdModule.forward(self, input1, input2, eps, iters)
#      58 def forward(self, input1, input2, eps, iters):
# ---> 59     return emdFunction.apply(input1, input2, eps, iters)
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/function.py:506, in Function.apply(cls, *args, **kwargs)
#     503 if not torch._C._are_functorch_transforms_active():
#     504     # See NOTE: [functorch vjp and autograd interaction]
#     505     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 506     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     508 if cls.setup_context == _SingleLevelFunction.setup_context:
#     509     raise RuntimeError(
#     510         'In order to use an autograd.Function with functorch transforms '
#     511         '(vmap, grad, jvp, jacrev, ...), it must override the setup_context '
#     512         'staticmethod. For more details, please see '
#     513         'https://pytorch.org/docs/master/notes/extending.func.html')
#
# Cell In[46], line 38, in emdFunction.forward(ctx, xyz1, xyz2, eps, iters)
#      35 unass_cnt_sum = torch.zeros(512, dtype=torch.int32, device='cuda').contiguous()
#      36 cnt_tmp = torch.zeros(512, dtype=torch.int32, device='cuda').contiguous()
# ---> 38 emd.forward(xyz1, xyz2, dist, assignment, price, assignment_inv, bid, bid_increments, max_increments, unass_idx, unass_cnt, unass_cnt_sum, cnt_tmp, max_idx, eps, iters)
#      40 ctx.save_for_backward(xyz1, xyz2, assignment)
#      41 return dist, assignment
#
# AttributeError: module 'emd' has no attribute 'forward'
