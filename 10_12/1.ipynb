# %%
from stage1 import *
from stage2 import *

# %%
decoded =[[10.6543,  9.8072, 10.6584,  0.1524,  8.0100],
          [10.6178,  9.7427, 10.5943,  0.1538,  7.8587],
          [10.6082,  9.7340, 10.5848,  0.1538,  7.8594]]

# %%
decoded = np.array(decoded)

# %%
input_arr = [[10.7963,  9.9279, 10.7336,  0.1520,  8.0000],
             [10.7943,  9.9253, 10.7218,  0.1520,  8.0000],
             [10.7817,  9.9124, 10.7052,  0.1520,  8.0000]]

# %%
input_arr = np.array(input)

# %%
fig=plt.figure(figsize=(10, 10))
ax=plt.axes(projection='3d')
ax.scatter3D(decoded[:,0], decoded[:,1], decoded[:,2], c='r', marker='o')
ax.scatter3D(input_arr [:,0], input_arr [:,1], input_arr [:,2], c='b', marker='o')
