# %%
import mdtraj as md
from ase import Atoms
import nglview as nv
import networkx as nx

import torch
import torch_geometric.transforms as T
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, SAGPooling, InnerProductDecoder
import torch_geometric.data as data
from torch_geometric.utils.convert import to_networkx

import numpy as np
import matplotlib.pyplot as plt

# %%
# loading the xtc and gro file into mdtraj
traj = md.load('eql2.xtc', top='conf.gro')

# %%
# creating the frame feature matrix
nframes = traj.xyz.shape[0]
natoms=traj.topology.residue(0).n_atoms
nmols=traj.topology.n_residues
frame_feature=[]
for i in range(nframes):
    com_pos=[] # position of Center of Mass of each molecule
    for res in range(nmols):
        com_pos.append(traj.xyz[i][res*natoms:(res+1)*natoms].mean(axis=0))
    frame_feature.append(com_pos)
frame_feature=np.array(frame_feature)
print(frame_feature.shape)
# Out:
# (51, 592, 3)

# %%
# creating the edge index matrix
cutoff=0.5
all_edge_list=[]
for i in range(nframes):
    fromlist=[]
    tolist=[]
    for j in range(nmols):
        for k in range(j+1,nmols):
            if np.linalg.norm(frame_feature[i][j]-frame_feature[i][k])<cutoff:
                fromlist.append(j)
                tolist.append(k)
                tolist.append(j)
                fromlist.append(k)
    edgelist=np.array([fromlist,tolist]).astype(np.int64)
    all_edge_list.append(edgelist)
print(len(all_edge_list))
# Out:
# 51

# %%
def convert_to_adj(edge_index, num_nodes=None):
    if num_nodes is None:
        num_nodes = edge_index.max() + 1
    adj = torch.zeros(num_nodes, num_nodes)
    adj[edge_index[0], edge_index[1]] = 1
    return adj

def convert_to_edge_index(adj):
    edge_index = adj.nonzero().t()
    return edge_index
frame = 10
plt.figure(figsize=(15,10))
adj_binary = convert_to_adj(all_edge_list[frame], num_nodes=592)
indices = torch.where(adj_binary)
G = nx.Graph()
edges = [(i, j) for i, j in zip(indices[0].tolist(), indices[1].tolist()) if i != j]
G.add_edges_from(edges)
nx.draw_networkx(G)

# %%
graphs = []
for frame in range(nframes):
    g = data.Data(x=torch.tensor(frame_feature[frame]).float(), edge_index=torch.tensor(all_edge_list[frame]).long(), y=torch.tensor([0]))
    graphs.append(g)

print(graphs[0])
# Out:
# Data(x=[592, 3], edge_index=[2, 7968], y=[1])

# %%
# import model.
from model import *

# %%
input_dim = graphs[0].num_features
output_dim = 2
lr=1e-4
epochs=100
batch_size=1
model=VGAE(VariationalGCNEncoder(input_dim, output_dim),
           VariationalGCNDecoder(output_dim,input_dim))
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
from pytorch3d.loss import chamfer_distance

# %%
train_loader_set = DataLoader(graphs[:int(nframes*0.6)], batch_size=batch_size, shuffle=True)
validation_loader_set = DataLoader(graphs[int(nframes*0.6):int(nframes*0.8)], batch_size=batch_size, shuffle=True)
test_loader_set = DataLoader(graphs[int(nframes*0.8):], batch_size=batch_size, shuffle=True)

# %%
for data in train_loader_set:
    z,encoded_edgeindex=model.encode(data.x,data.edge_index)
    decodedx,decoded_edgeindex=model.decode(z,encoded_edgeindex)
    # print(data)
    print(decodedx)
    print("data.x")
    print(data.x)
    print("sizes")
    print(decodedx.size())
    print(data.x.size())
# Out:
# tensor([[-0.0364, -0.0094, -0.0598],
#         [-0.0123, -0.0344,  0.0277],
#         [-0.0018, -0.0023, -0.0015],
#         ...,
#         [-0.0253, -0.0120, -0.0324],
#         [-0.0869, -0.0450, -0.1049],
#         [-0.0158, -0.0033, -0.0272]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.2075, 0.0610, 0.1970],
#         [1.7150, 0.4753, 1.1825],
#         [0.5010, 0.3520, 0.4270],
#         ...,
#         [1.4815, 1.9358, 1.2370],
#         [0.4125, 1.4688, 2.0345],
#         [1.3463, 1.3150, 1.0228]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0045,  0.0061, -0.0023],
#         [-0.0499, -0.0336, -0.0489],
#         [-0.0164,  0.0021, -0.0370],
#         ...,
#         [-0.0047,  0.0019, -0.0139],
#         [-0.0105, -0.0083, -0.0084],
#         [-0.0023, -0.0084,  0.0068]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.5780, 1.4200, 0.2418],
#         [1.2730, 1.9433, 0.8568],
#         [0.6438, 0.8598, 1.2458],
#         ...,
#         [0.9643, 0.8875, 0.9375],
#         [1.2493, 0.1208, 1.2738],
#         [2.2815, 1.8110, 1.7660]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0126, -0.0024,  0.0281],
#         [ 0.0272,  0.0092,  0.0378],
#         [-0.0399, -0.0145, -0.0585],
#         ...,
#         [-0.0416, -0.0198, -0.0529],
#         [-0.0650, -0.0391, -0.0702],
#         [ 0.0047,  0.0074, -0.0033]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.5603, 2.4588, 0.3390],
#         [1.4748, 0.4055, 1.2428],
#         [0.6510, 0.4600, 0.8393],
#         ...,
#         [1.2353, 2.0775, 1.3558],
#         [0.4368, 1.4852, 2.2945],
#         [1.3817, 1.5340, 1.2070]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0109, -0.0118, -0.0038],
#         [ 0.0184,  0.0146,  0.0116],
#         [-0.0320, -0.0187, -0.0354],
#         ...,
#         [-0.0381, -0.0236, -0.0406],
#         [-0.0194, -0.0117, -0.0209],
#         [-0.0090,  0.0029, -0.0234]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[2.6850e-01, 5.4500e-01, 9.8875e-01],
#         [1.7370e+00, 1.0000e-03, 2.1300e+00],
#         [6.9925e-01, 1.8663e+00, 1.2330e+00],
#         ...,
#         [1.0113e+00, 1.2320e+00, 3.9425e-01],
#         [2.3245e+00, 1.3450e+00, 1.8760e+00],
#         [9.6100e-01, 2.3690e+00, 4.3125e-01]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0414,  0.0266,  0.0371],
#         [-0.0306, -0.0368, -0.0053],
#         [ 0.0092,  0.0075,  0.0054],
#         ...,
#         [ 0.0122,  0.0211, -0.0136],
#         [ 0.0191,  0.0228, -0.0043],
#         [-0.0190, -0.0115, -0.0202]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.1303, 0.3768, 0.0753],
#         [2.1190, 1.9520, 0.4970],
#         [0.1928, 0.9333, 0.2020],
#         ...,
#         [2.3110, 0.0830, 1.4310],
#         [1.6018, 1.0440, 0.1828],
#         [0.2790, 2.3650, 0.7355]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0142,  0.0013,  0.0256],
#         [ 0.0078,  0.0090,  0.0003],
#         [ 0.0033,  0.0013,  0.0039],
#         ...,
#         [-0.0108, -0.0046, -0.0150],
#         [-0.0534, -0.0321, -0.0577],
#         [-0.0502, -0.0234, -0.0641]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.2555, 1.3758, 0.0265],
#         [1.6193, 2.3788, 1.0293],
#         [1.2010, 0.9043, 1.1900],
#         ...,
#         [0.8203, 1.1618, 0.8240],
#         [0.7033, 2.1573, 0.9293],
#         [0.0965, 2.0033, 1.6012]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0063,  0.0032, -0.0196],
#         [-0.0119, -0.0059, -0.0154],
#         [-0.0175, -0.0095, -0.0208],
#         ...,
#         [-0.0310, -0.0381, -0.0039],
#         [-0.0218, -0.0111, -0.0282],
#         [-0.0330, -0.0181, -0.0388]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.8513, 1.8950, 0.1175],
#         [1.1925, 1.9108, 0.7247],
#         [0.3995, 0.9195, 1.2380],
#         ...,
#         [1.5853, 0.7310, 1.4365],
#         [1.2535, 0.2340, 1.0530],
#         [1.9798, 2.3490, 2.1405]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0153,  0.0013,  0.0276],
#         [-0.0006, -0.0310,  0.0467],
#         [-0.0078, -0.0089, -0.0030],
#         ...,
#         [-0.0300, -0.0176, -0.0335],
#         [-0.0145, -0.0203,  0.0019],
#         [-0.0558, -0.0372, -0.0551]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.8265, 1.7195, 0.0120],
#         [1.6930, 0.2273, 0.2300],
#         [0.5330, 0.1835, 0.7363],
#         ...,
#         [2.0113, 0.8998, 1.4160],
#         [1.6925, 0.9448, 1.1918],
#         [1.3643, 2.0425, 2.3740]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0073,  0.0022, -0.0188],
#         [ 0.0102,  0.0094,  0.0039],
#         [ 0.0013, -0.0182,  0.0307],
#         ...,
#         [-0.0625, -0.0318, -0.0767],
#         [-0.0039,  0.0101, -0.0260],
#         [-0.0201, -0.0254, -0.0019]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.0362, 1.7175, 2.5475],
#         [1.6182, 1.9955, 0.9453],
#         [0.7670, 0.4965, 0.5880],
#         ...,
#         [0.7188, 1.1238, 1.7015],
#         [0.8208, 1.8695, 0.2845],
#         [2.3788, 1.8915, 1.2430]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0226,  0.0015,  0.0412],
#         [ 0.0295,  0.0246,  0.0150],
#         [-0.0501, -0.0271, -0.0588],
#         ...,
#         [-0.0146, -0.0218,  0.0034],
#         [-0.0804, -0.0549, -0.0785],
#         [-0.0445, -0.0226, -0.0545]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[2.1597, 0.1850, 0.7457],
#         [1.5728, 0.2555, 0.8068],
#         [0.6727, 0.8580, 1.9285],
#         ...,
#         [1.4625, 1.5775, 0.7468],
#         [0.3145, 1.9950, 2.0148],
#         [1.0948, 1.8858, 0.4628]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0334, -0.0280, -0.0239],
#         [-0.0201, -0.0286,  0.0034],
#         [-0.0149,  0.0055, -0.0402],
#         ...,
#         [-0.0669, -0.0462, -0.0643],
#         [ 0.0144, -0.0013,  0.0297],
#         [-0.0570, -0.0305, -0.0672]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.5120, 0.1632, 2.6083],
#         [1.6520, 2.5690, 0.7968],
#         [0.8310, 1.2483, 2.5707],
#         ...,
#         [0.7143, 2.1353, 1.2893],
#         [1.7995, 1.8490, 0.5433],
#         [0.2375, 0.2300, 0.3208]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0320, -0.0183, -0.0371],
#         [ 0.0146, -0.0015,  0.0295],
#         [ 0.0193,  0.0250, -0.0063],
#         ...,
#         [-0.0101,  0.0037, -0.0270],
#         [ 0.0173,  0.0184,  0.0026],
#         [-0.0821, -0.0479, -0.0914]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.8238, 2.2448, 0.1730],
#         [2.2235, 0.6293, 0.2490],
#         [0.7528, 0.5370, 0.5103],
#         ...,
#         [2.3035, 0.9363, 1.3510],
#         [1.4763, 1.0108, 1.1782],
#         [0.6605, 2.3005, 2.4445]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0257,  0.0210,  0.0106],
#         [-0.0005, -0.0195,  0.0266],
#         [ 0.0062,  0.0134, -0.0115],
#         ...,
#         [-0.0158, -0.0142, -0.0120],
#         [-0.1249, -0.0731, -0.1408],
#         [ 0.0096,  0.0037,  0.0095]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.8315, 0.1858, 0.3383],
#         [1.7290, 0.5332, 1.3355],
#         [0.5510, 0.5808, 0.2075],
#         ...,
#         [1.8130, 1.9058, 0.9480],
#         [0.5920, 1.9370, 2.1855],
#         [1.3545, 1.0583, 0.6003]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0326, -0.0204, -0.0337],
#         [ 0.0008,  0.0108, -0.0180],
#         [ 0.0037,  0.0112, -0.0123],
#         ...,
#         [-0.0026, -0.0129,  0.0120],
#         [ 0.0264, -0.0024,  0.0546],
#         [-0.0403, -0.0250, -0.0421]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.2448, 2.4478, 2.5382],
#         [1.4400, 2.4360, 0.5755],
#         [0.1250, 0.2490, 0.4045],
#         ...,
#         [2.5013, 0.8153, 1.4758],
#         [1.3738, 0.8893, 0.2993],
#         [0.3085, 2.0463, 1.4085]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0311, -0.0228, -0.0274],
#         [-0.0459, -0.0238, -0.0550],
#         [ 0.0111,  0.0007,  0.0207],
#         ...,
#         [-0.0923, -0.0579, -0.0983],
#         [-0.0287, -0.0509,  0.0208],
#         [ 0.0357,  0.0338,  0.0121]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.6215, 2.4483, 0.4038],
#         [1.4015, 2.4130, 0.9073],
#         [1.0957, 1.2033, 0.1553],
#         ...,
#         [0.3560, 1.9858, 0.8335],
#         [2.3655, 2.2038, 2.5780],
#         [2.2045, 2.5905, 0.0345]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0373,  0.0339,  0.0136],
#         [ 0.0185,  0.0119,  0.0163],
#         [-0.0227, -0.0068, -0.0366],
#         ...,
#         [ 0.0166,  0.0208, -0.0047],
#         [-0.0213, -0.0109, -0.0266],
#         [-0.0584, -0.0381, -0.0587]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.3598, 0.4863, 0.0565],
#         [2.1150, 2.2945, 0.3555],
#         [0.5865, 0.9695, 0.3058],
#         ...,
#         [2.2333, 2.2555, 1.3535],
#         [1.5255, 1.2705, 0.4940],
#         [0.1690, 2.1883, 0.7617]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0527, -0.0308, -0.0584],
#         [-0.0098,  0.0024, -0.0257],
#         [-0.0031,  0.0056, -0.0161],
#         ...,
#         [-0.0677, -0.0393, -0.0755],
#         [-0.0239, -0.0144, -0.0270],
#         [-0.0218, -0.0141, -0.0219]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[0.4788, 0.6640, 0.5412],
#         [1.8720, 0.3500, 2.1523],
#         [1.3035, 1.9785, 1.1250],
#         ...,
#         [0.7845, 1.8340, 2.6413],
#         [1.9722, 1.8178, 1.9973],
#         [1.1808, 2.3043, 0.6615]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0123,  0.0117,  0.0046],
#         [-0.0164, -0.0070, -0.0222],
#         [-0.0127, -0.0078, -0.0138],
#         ...,
#         [-0.0369, -0.0108, -0.0577],
#         [-0.0302, -0.0361, -0.0053],
#         [-0.0352, -0.0253, -0.0316]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[2.0048, 2.0325, 0.2830],
#         [1.3235, 2.0500, 0.4392],
#         [0.4998, 0.7418, 0.6050],
#         ...,
#         [1.4773, 0.6325, 1.5070],
#         [0.8820, 0.0405, 1.0365],
#         [2.1950, 1.9925, 1.7260]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0227, -0.0037, -0.0408],
#         [ 0.0023, -0.0031,  0.0084],
#         [-0.0256, -0.0152, -0.0294],
#         ...,
#         [-0.0737, -0.0361, -0.0921],
#         [-0.0342, -0.0368, -0.0124],
#         [-0.0213, -0.0074, -0.0318]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[0.7473, 0.6945, 0.4960],
#         [1.5425, 0.5288, 1.7060],
#         [1.0853, 2.2552, 1.5267],
#         ...,
#         [0.4347, 2.4148, 1.9922],
#         [1.7770, 1.9385, 2.4698],
#         [0.9855, 1.7758, 0.4230]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0387, -0.0319, -0.0305],
#         [-0.0392, -0.0194, -0.0507],
#         [-0.0241, -0.0034, -0.0440],
#         ...,
#         [-0.0610, -0.0429, -0.0569],
#         [-0.0769, -0.0506, -0.0779],
#         [-0.0107, -0.0167,  0.0018]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.4943, 2.4015, 0.7212],
#         [1.4430, 2.4175, 1.0347],
#         [1.0423, 0.5513, 0.4658],
#         ...,
#         [0.6335, 2.1072, 0.8630],
#         [0.2217, 2.2410, 2.5220],
#         [1.6430, 2.4025, 0.2088]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.1556, -0.0991, -0.1705],
#         [-0.0239, -0.0187, -0.0191],
#         [-0.0714, -0.0705, -0.0388],
#         ...,
#         [-0.0608, -0.0312, -0.0738],
#         [-0.0356, -0.0273, -0.0294],
#         [-0.0029, -0.0432,  0.0614]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.7925, 0.2728, 2.6195],
#         [1.5315, 2.0490, 0.8490],
#         [0.9555, 1.2733, 0.1055],
#         ...,
#         [0.5188, 1.9880, 1.1495],
#         [1.7418, 2.1520, 0.5605],
#         [2.2165, 0.1150, 0.2333]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0067, -0.0057, -0.0063],
#         [-0.0375, -0.0313, -0.0270],
#         [-0.0093,  0.0018, -0.0228],
#         ...,
#         [-0.0706, -0.0687, -0.0397],
#         [-0.0556, -0.0262, -0.0706],
#         [-0.0151, -0.0228,  0.0047]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.5848, 2.3447, 0.5738],
#         [1.4640, 2.2705, 1.0680],
#         [1.0390, 0.8975, 0.7858],
#         ...,
#         [0.7758, 1.9143, 0.7620],
#         [0.6675, 1.9693, 2.0653],
#         [1.4212, 1.6940, 0.5598]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0362, -0.0180, -0.0443],
#         [-0.0021,  0.0130, -0.0282],
#         [-0.0204, -0.0230, -0.0067],
#         ...,
#         [-0.0276, -0.0148, -0.0327],
#         [-0.0274, -0.0157, -0.0308],
#         [ 0.0380,  0.0435, -0.0036]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[0.9083, 1.2910, 2.5070],
#         [1.7913, 2.2923, 1.3288],
#         [1.3335, 0.4258, 1.0610],
#         ...,
#         [0.6345, 0.6123, 0.9690],
#         [0.8493, 1.9073, 0.5355],
#         [2.3195, 2.1425, 1.4660]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0411,  0.0111,  0.0629],
#         [-0.0127,  0.0030, -0.0314],
#         [-0.0258, -0.0092, -0.0376],
#         ...,
#         [ 0.0446,  0.0345,  0.0302],
#         [-0.0631, -0.0386, -0.0675],
#         [ 0.0175,  0.0068,  0.0236]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[2.0038, 0.1610, 0.1405],
#         [1.4863, 0.4090, 1.2995],
#         [1.1265, 0.7360, 2.4720],
#         ...,
#         [1.5523, 1.9758, 0.5288],
#         [0.6425, 1.7800, 2.2068],
#         [0.9280, 1.5195, 0.6255]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0149,  0.0092,  0.0139],
#         [ 0.0169,  0.0086,  0.0177],
#         [-0.0170, -0.0131, -0.0144],
#         ...,
#         [-0.0052, -0.0012, -0.0098],
#         [-0.0192, -0.0220, -0.0045],
#         [-0.0866, -0.0464, -0.1027]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.3613, 1.9870, 0.1493],
#         [1.6295, 0.5132, 0.5898],
#         [0.5473, 0.4737, 0.2803],
#         ...,
#         [0.2838, 0.5983, 1.8135],
#         [1.2510, 1.1810, 0.3063],
#         [0.5910, 2.0073, 1.4333]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0360,  0.0361,  0.0085],
#         [-0.0063,  0.0065, -0.0238],
#         [ 0.0021, -0.0095,  0.0183],
#         ...,
#         [ 0.0255,  0.0083,  0.0360],
#         [ 0.0074, -0.0119,  0.0330],
#         [-0.0636, -0.0435, -0.0616]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[2.1523, 2.0017, 0.0218],
#         [1.8363, 2.3988, 0.3808],
#         [0.7913, 0.0225, 0.6968],
#         ...,
#         [1.5785, 0.9270, 1.4015],
#         [1.3750, 0.2790, 1.4353],
#         [1.6625, 1.9335, 2.1058]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0453,  0.0357,  0.0285],
#         [-0.0189, -0.0130, -0.0186],
#         [ 0.0376,  0.0364,  0.0086],
#         ...,
#         [-0.0281, -0.0126, -0.0373],
#         [-0.0018, -0.0024, -0.0011],
#         [-0.0571, -0.0349, -0.0609]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.4728, 0.0723, 0.0738],
#         [2.1115, 2.2540, 0.6585],
#         [0.3615, 1.1025, 0.3435],
#         ...,
#         [1.7865, 2.2713, 1.2943],
#         [1.5758, 1.2983, 0.2263],
#         [0.4108, 2.1128, 0.8153]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0573, -0.0340, -0.0632],
#         [-0.0326, -0.0187, -0.0368],
#         [-0.0480, -0.0272, -0.0541],
#         ...,
#         [-0.0243, -0.0032, -0.0458],
#         [ 0.0019,  0.0118, -0.0162],
#         [-0.0163, -0.0118, -0.0143]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[0.0800, 0.3598, 0.8798],
#         [1.7235, 0.7170, 2.5668],
#         [0.6978, 1.1263, 1.6195],
#         ...,
#         [1.5870, 1.6300, 0.2248],
#         [0.0925, 2.0573, 2.0250],
#         [0.9345, 2.1513, 0.4628]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[-0.0293, -0.0103, -0.0452],
#         [-0.0264, -0.0035, -0.0479],
#         [-0.0156,  0.0031, -0.0431],
#         ...,
#         [-0.0033,  0.0040, -0.0141],
#         [-0.0589, -0.0289, -0.0732],
#         [-0.0069, -0.0094, -0.0004]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.5995, 2.6218, 0.2455],
#         [1.3575, 2.5835, 1.0558],
#         [1.0793, 0.6508, 0.4993],
#         ...,
#         [1.3380, 2.0070, 1.0448],
#         [0.2318, 1.4180, 1.8148],
#         [1.3720, 1.5545, 1.1570]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])
# tensor([[ 0.0189,  0.0154,  0.0118],
#         [-0.0031, -0.0114,  0.0104],
#         [-0.0445, -0.0353, -0.0362],
#         ...,
#         [-0.0359, -0.0128, -0.0525],
#         [ 0.0161,  0.0124,  0.0112],
#         [-0.0106,  0.0021, -0.0256]], grad_fn=<SiluBackward0>)
# data.x
# tensor([[1.4540, 1.8093, 0.3678],
#         [1.9528, 2.1980, 0.3913],
#         [0.7418, 0.4302, 0.5713],
#         ...,
#         [0.5723, 0.7158, 1.4298],
#         [1.1068, 1.8303, 0.1968],
#         [2.4140, 2.0573, 1.5668]])
# sizes
# torch.Size([592, 3])
# torch.Size([592, 3])

# %%
lossFxn = torch.nn.MSELoss()
def train():
    model.train()
    model.zero_grad()
    model.float()
    loss_all = 0
    feature_loss_all = 0
    edge_loss_all = 0
    kl_loss_all = 0
    closs_all=0
    for data in train_loader_set:
        optimizer.zero_grad()
        z,encoded_edge_index = model.encode(data.x, data.edge_index)
        decoded_x, decoded_edge_index = model.decode(z, encoded_edge_index)
        out2=decoded_x.reshape(1,592,3)
        in2=data.x.reshape(1,592,3)
        closs=chamfer_distance(out2,in2)
        # print(closs[0])
        closs=closs[0]
        closs=torch.tensor(closs, dtype=torch.float32)
        FeatureLoss = lossFxn(decoded_x, data.x)
        EdgeLoss = lossFxn(decoded_edge_index.float(), data.edge_index)
        # loss = FeatureLoss + EdgeLoss 
        loss = FeatureLoss + EdgeLoss + closs
        loss = loss 
        closs_all+=float(closs)
        loss_all +=  float(loss)
        feature_loss_all += float(FeatureLoss)
        edge_loss_all += float(EdgeLoss)
        kl_loss_all += float(model.kl_loss()/data.num_nodes)

        loss.backward()
        optimizer.step()

        

    return loss_all / len(train_loader_set.dataset),closs_all/len(train_loader_set.dataset), feature_loss_all / len(train_loader_set.dataset), edge_loss_all / len(train_loader_set.dataset), kl_loss_all / len(train_loader_set.dataset)

# %%
total_losses = []
feature_losses = []
edge_losses = []
kl_losses = []
cd_losses=[]
for epoch in range(1, epochs+ 1):
    total_loss, cd_loss,feature_loss, edge_loss, kl_loss = train()
    print(f'Epoch: {epoch:03d}')
    print(f'TRAIN : Total Loss: {total_loss:.4f}, CD Loss : {cd_loss:.4f}, Feature Loss: {feature_loss:.4f}, Edge Loss: {edge_loss:.4f}')
    total_losses.append(total_loss)
    feature_losses.append(feature_loss)
    edge_losses.append(edge_loss)
    kl_losses.append(kl_loss)
    cd_losses.append(cd_loss)
# Out:
# /tmp/ipykernel_23499/1287167025.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   closs=torch.tensor(closs, dtype=torch.float32)
# Epoch: 001
# TRAIN : Total Loss: 8.8597, CD Loss : 6.5368, Feature Loss: 2.3228, Edge Loss: 0.0000
# Epoch: 002
# TRAIN : Total Loss: 8.7845, CD Loss : 6.4716, Feature Loss: 2.3129, Edge Loss: 0.0000
# Epoch: 003
# TRAIN : Total Loss: 8.7753, CD Loss : 6.4755, Feature Loss: 2.2998, Edge Loss: 0.0000
# Epoch: 004
# TRAIN : Total Loss: 8.7574, CD Loss : 6.4657, Feature Loss: 2.2918, Edge Loss: 0.0000
# Epoch: 005
# TRAIN : Total Loss: 8.7208, CD Loss : 6.4396, Feature Loss: 2.2813, Edge Loss: 0.0000
# Epoch: 006
# TRAIN : Total Loss: 8.6743, CD Loss : 6.4086, Feature Loss: 2.2656, Edge Loss: 0.0000
# Epoch: 007
# TRAIN : Total Loss: 8.6003, CD Loss : 6.3461, Feature Loss: 2.2543, Edge Loss: 0.0000
# Epoch: 008
# TRAIN : Total Loss: 8.5956, CD Loss : 6.3478, Feature Loss: 2.2478, Edge Loss: 0.0000
# Epoch: 009
# TRAIN : Total Loss: 8.5140, CD Loss : 6.2800, Feature Loss: 2.2340, Edge Loss: 0.0000
# Epoch: 010
# TRAIN : Total Loss: 8.4944, CD Loss : 6.2713, Feature Loss: 2.2231, Edge Loss: 0.0000
# Epoch: 011
# TRAIN : Total Loss: 8.4927, CD Loss : 6.2738, Feature Loss: 2.2190, Edge Loss: 0.0000
# Epoch: 012
# TRAIN : Total Loss: 8.3718, CD Loss : 6.1705, Feature Loss: 2.2013, Edge Loss: 0.0000
# Epoch: 013
# TRAIN : Total Loss: 8.3465, CD Loss : 6.1507, Feature Loss: 2.1958, Edge Loss: 0.0000
# Epoch: 014
# TRAIN : Total Loss: 8.2845, CD Loss : 6.1041, Feature Loss: 2.1804, Edge Loss: 0.0000
# Epoch: 015
# TRAIN : Total Loss: 8.2134, CD Loss : 6.0494, Feature Loss: 2.1640, Edge Loss: 0.0000
# Epoch: 016
# TRAIN : Total Loss: 8.1192, CD Loss : 5.9697, Feature Loss: 2.1495, Edge Loss: 0.0000
# Epoch: 017
# TRAIN : Total Loss: 8.0677, CD Loss : 5.9318, Feature Loss: 2.1360, Edge Loss: 0.0000
# Epoch: 018
# TRAIN : Total Loss: 7.9824, CD Loss : 5.8526, Feature Loss: 2.1298, Edge Loss: 0.0000
# Epoch: 019
# TRAIN : Total Loss: 7.9185, CD Loss : 5.8051, Feature Loss: 2.1133, Edge Loss: 0.0000
# Epoch: 020
# TRAIN : Total Loss: 7.8093, CD Loss : 5.7153, Feature Loss: 2.0940, Edge Loss: 0.0000
# Epoch: 021
# TRAIN : Total Loss: 7.6864, CD Loss : 5.6090, Feature Loss: 2.0774, Edge Loss: 0.0000
# Epoch: 022
# TRAIN : Total Loss: 7.6503, CD Loss : 5.5858, Feature Loss: 2.0645, Edge Loss: 0.0000
# Epoch: 023
# TRAIN : Total Loss: 7.5280, CD Loss : 5.4809, Feature Loss: 2.0471, Edge Loss: 0.0000
# Epoch: 024
# TRAIN : Total Loss: 7.4503, CD Loss : 5.4177, Feature Loss: 2.0326, Edge Loss: 0.0000
# Epoch: 025
# TRAIN : Total Loss: 7.3654, CD Loss : 5.3580, Feature Loss: 2.0074, Edge Loss: 0.0000
# Epoch: 026
# TRAIN : Total Loss: 7.1740, CD Loss : 5.1943, Feature Loss: 1.9797, Edge Loss: 0.0000
# Epoch: 027
# TRAIN : Total Loss: 7.0556, CD Loss : 5.0886, Feature Loss: 1.9670, Edge Loss: 0.0000
# Epoch: 028
# TRAIN : Total Loss: 6.9380, CD Loss : 4.9990, Feature Loss: 1.9389, Edge Loss: 0.0000
# Epoch: 029
# TRAIN : Total Loss: 6.8352, CD Loss : 4.9163, Feature Loss: 1.9188, Edge Loss: 0.0000
# Epoch: 030
# TRAIN : Total Loss: 6.6158, CD Loss : 4.7339, Feature Loss: 1.8820, Edge Loss: 0.0000
# Epoch: 031
# TRAIN : Total Loss: 6.4757, CD Loss : 4.6120, Feature Loss: 1.8637, Edge Loss: 0.0000
# Epoch: 032
# TRAIN : Total Loss: 6.3117, CD Loss : 4.4839, Feature Loss: 1.8279, Edge Loss: 0.0000
# Epoch: 033
# TRAIN : Total Loss: 6.1606, CD Loss : 4.3607, Feature Loss: 1.7999, Edge Loss: 0.0000
# Epoch: 034
# TRAIN : Total Loss: 5.9948, CD Loss : 4.2283, Feature Loss: 1.7666, Edge Loss: 0.0000
# Epoch: 035
# TRAIN : Total Loss: 5.8252, CD Loss : 4.0913, Feature Loss: 1.7339, Edge Loss: 0.0000
# Epoch: 036
# TRAIN : Total Loss: 5.5923, CD Loss : 3.8964, Feature Loss: 1.6958, Edge Loss: 0.0000
# Epoch: 037
# TRAIN : Total Loss: 5.4118, CD Loss : 3.7513, Feature Loss: 1.6605, Edge Loss: 0.0000
# Epoch: 038
# TRAIN : Total Loss: 5.2557, CD Loss : 3.6372, Feature Loss: 1.6185, Edge Loss: 0.0000
# Epoch: 039
# TRAIN : Total Loss: 5.0383, CD Loss : 3.4601, Feature Loss: 1.5782, Edge Loss: 0.0000
# Epoch: 040
# TRAIN : Total Loss: 4.8001, CD Loss : 3.2648, Feature Loss: 1.5353, Edge Loss: 0.0000
# Epoch: 041
# TRAIN : Total Loss: 4.6369, CD Loss : 3.1425, Feature Loss: 1.4944, Edge Loss: 0.0000
# Epoch: 042
# TRAIN : Total Loss: 4.3974, CD Loss : 2.9552, Feature Loss: 1.4422, Edge Loss: 0.0000
# Epoch: 043
# TRAIN : Total Loss: 4.1995, CD Loss : 2.7966, Feature Loss: 1.4029, Edge Loss: 0.0000
# Epoch: 044
# TRAIN : Total Loss: 3.9385, CD Loss : 2.5969, Feature Loss: 1.3416, Edge Loss: 0.0000
# Epoch: 045
# TRAIN : Total Loss: 3.8031, CD Loss : 2.5020, Feature Loss: 1.3011, Edge Loss: 0.0000
# Epoch: 046
# TRAIN : Total Loss: 3.5489, CD Loss : 2.3009, Feature Loss: 1.2480, Edge Loss: 0.0000
# Epoch: 047
# TRAIN : Total Loss: 3.3617, CD Loss : 2.1680, Feature Loss: 1.1937, Edge Loss: 0.0000
# Epoch: 048
# TRAIN : Total Loss: 3.2019, CD Loss : 2.0522, Feature Loss: 1.1497, Edge Loss: 0.0000
# Epoch: 049
# TRAIN : Total Loss: 2.9857, CD Loss : 1.8890, Feature Loss: 1.0967, Edge Loss: 0.0000
# Epoch: 050
# TRAIN : Total Loss: 2.8461, CD Loss : 1.7968, Feature Loss: 1.0493, Edge Loss: 0.0000
# Epoch: 051
# TRAIN : Total Loss: 2.6736, CD Loss : 1.6735, Feature Loss: 1.0000, Edge Loss: 0.0000
# Epoch: 052
# TRAIN : Total Loss: 2.5417, CD Loss : 1.5858, Feature Loss: 0.9560, Edge Loss: 0.0000
# Epoch: 053
# TRAIN : Total Loss: 2.3978, CD Loss : 1.4907, Feature Loss: 0.9071, Edge Loss: 0.0000
# Epoch: 054
# TRAIN : Total Loss: 2.3160, CD Loss : 1.4431, Feature Loss: 0.8729, Edge Loss: 0.0000
# Epoch: 055
# TRAIN : Total Loss: 2.2038, CD Loss : 1.3691, Feature Loss: 0.8347, Edge Loss: 0.0000
# Epoch: 056
# TRAIN : Total Loss: 2.1187, CD Loss : 1.3231, Feature Loss: 0.7956, Edge Loss: 0.0000
# Epoch: 057
# TRAIN : Total Loss: 2.0480, CD Loss : 1.2835, Feature Loss: 0.7644, Edge Loss: 0.0000
# Epoch: 058
# TRAIN : Total Loss: 1.9828, CD Loss : 1.2509, Feature Loss: 0.7318, Edge Loss: 0.0000
# Epoch: 059
# TRAIN : Total Loss: 1.9364, CD Loss : 1.2262, Feature Loss: 0.7102, Edge Loss: 0.0000
# Epoch: 060
# TRAIN : Total Loss: 1.8874, CD Loss : 1.1989, Feature Loss: 0.6885, Edge Loss: 0.0000
# Epoch: 061
# TRAIN : Total Loss: 1.8496, CD Loss : 1.1811, Feature Loss: 0.6685, Edge Loss: 0.0000
# Epoch: 062
# TRAIN : Total Loss: 1.8219, CD Loss : 1.1683, Feature Loss: 0.6536, Edge Loss: 0.0000
# Epoch: 063
# TRAIN : Total Loss: 1.7987, CD Loss : 1.1539, Feature Loss: 0.6448, Edge Loss: 0.0000
# Epoch: 064
# TRAIN : Total Loss: 1.7918, CD Loss : 1.1566, Feature Loss: 0.6352, Edge Loss: 0.0000
# Epoch: 065
# TRAIN : Total Loss: 1.7641, CD Loss : 1.1428, Feature Loss: 0.6213, Edge Loss: 0.0000
# Epoch: 066
# TRAIN : Total Loss: 1.7394, CD Loss : 1.1269, Feature Loss: 0.6125, Edge Loss: 0.0000
# Epoch: 067
# TRAIN : Total Loss: 1.7378, CD Loss : 1.1267, Feature Loss: 0.6111, Edge Loss: 0.0000
# Epoch: 068
# TRAIN : Total Loss: 1.7199, CD Loss : 1.1190, Feature Loss: 0.6009, Edge Loss: 0.0000
# Epoch: 069
# TRAIN : Total Loss: 1.7200, CD Loss : 1.1220, Feature Loss: 0.5980, Edge Loss: 0.0000
# Epoch: 070
# TRAIN : Total Loss: 1.7106, CD Loss : 1.1134, Feature Loss: 0.5972, Edge Loss: 0.0000
# Epoch: 071
# TRAIN : Total Loss: 1.6885, CD Loss : 1.0999, Feature Loss: 0.5886, Edge Loss: 0.0000
# Epoch: 072
# TRAIN : Total Loss: 1.6830, CD Loss : 1.0977, Feature Loss: 0.5853, Edge Loss: 0.0000
# Epoch: 073
# TRAIN : Total Loss: 1.6753, CD Loss : 1.0882, Feature Loss: 0.5871, Edge Loss: 0.0000
# Epoch: 074
# TRAIN : Total Loss: 1.6754, CD Loss : 1.0916, Feature Loss: 0.5839, Edge Loss: 0.0000
# Epoch: 075
# TRAIN : Total Loss: 1.6585, CD Loss : 1.0817, Feature Loss: 0.5768, Edge Loss: 0.0000
# Epoch: 076
# TRAIN : Total Loss: 1.6577, CD Loss : 1.0827, Feature Loss: 0.5750, Edge Loss: 0.0000
# Epoch: 077
# TRAIN : Total Loss: 1.6590, CD Loss : 1.0851, Feature Loss: 0.5738, Edge Loss: 0.0000
# Epoch: 078
# TRAIN : Total Loss: 1.6515, CD Loss : 1.0789, Feature Loss: 0.5726, Edge Loss: 0.0000
# Epoch: 079
# TRAIN : Total Loss: 1.6494, CD Loss : 1.0753, Feature Loss: 0.5741, Edge Loss: 0.0000
# Epoch: 080
# TRAIN : Total Loss: 1.6358, CD Loss : 1.0673, Feature Loss: 0.5685, Edge Loss: 0.0000
# Epoch: 081
# TRAIN : Total Loss: 1.6255, CD Loss : 1.0629, Feature Loss: 0.5626, Edge Loss: 0.0000
# Epoch: 082
# TRAIN : Total Loss: 1.6337, CD Loss : 1.0683, Feature Loss: 0.5655, Edge Loss: 0.0000
# Epoch: 083
# TRAIN : Total Loss: 1.6211, CD Loss : 1.0578, Feature Loss: 0.5633, Edge Loss: 0.0000
# Epoch: 084
# TRAIN : Total Loss: 1.6152, CD Loss : 1.0577, Feature Loss: 0.5574, Edge Loss: 0.0000
# Epoch: 085
# TRAIN : Total Loss: 1.6044, CD Loss : 1.0454, Feature Loss: 0.5589, Edge Loss: 0.0000
# Epoch: 086
# TRAIN : Total Loss: 1.6064, CD Loss : 1.0477, Feature Loss: 0.5586, Edge Loss: 0.0000
# Epoch: 087
# TRAIN : Total Loss: 1.6083, CD Loss : 1.0518, Feature Loss: 0.5565, Edge Loss: 0.0000
# Epoch: 088
# TRAIN : Total Loss: 1.6054, CD Loss : 1.0496, Feature Loss: 0.5559, Edge Loss: 0.0000
# Epoch: 089
# TRAIN : Total Loss: 1.6049, CD Loss : 1.0499, Feature Loss: 0.5550, Edge Loss: 0.0000
# Epoch: 090
# TRAIN : Total Loss: 1.5975, CD Loss : 1.0462, Feature Loss: 0.5514, Edge Loss: 0.0000
# Epoch: 091
# TRAIN : Total Loss: 1.5914, CD Loss : 1.0423, Feature Loss: 0.5491, Edge Loss: 0.0000
# Epoch: 092
# TRAIN : Total Loss: 1.5866, CD Loss : 1.0391, Feature Loss: 0.5475, Edge Loss: 0.0000
# Epoch: 093
# TRAIN : Total Loss: 1.5833, CD Loss : 1.0391, Feature Loss: 0.5441, Edge Loss: 0.0000
# Epoch: 094
# TRAIN : Total Loss: 1.5734, CD Loss : 1.0328, Feature Loss: 0.5406, Edge Loss: 0.0000
# Epoch: 095
# TRAIN : Total Loss: 1.5740, CD Loss : 1.0314, Feature Loss: 0.5426, Edge Loss: 0.0000
# Epoch: 096
# TRAIN : Total Loss: 1.5806, CD Loss : 1.0367, Feature Loss: 0.5439, Edge Loss: 0.0000
# Epoch: 097
# TRAIN : Total Loss: 1.5752, CD Loss : 1.0354, Feature Loss: 0.5398, Edge Loss: 0.0000
# Epoch: 098
# TRAIN : Total Loss: 1.5761, CD Loss : 1.0344, Feature Loss: 0.5417, Edge Loss: 0.0000
# Epoch: 099
# TRAIN : Total Loss: 1.5686, CD Loss : 1.0300, Feature Loss: 0.5386, Edge Loss: 0.0000
# Epoch: 100
# TRAIN : Total Loss: 1.5637, CD Loss : 1.0299, Feature Loss: 0.5338, Edge Loss: 0.0000

# %%
plt.figure(figsize=(14, 5))
plt.plot(total_losses, label='Total Loss')
plt.plot(cd_losses, label='Chamfer Distance loss')
plt.plot(feature_losses, label='Feature loss')
plt.plot(edge_losses, label='Edge loss')
plt.plot(kl_losses, label='KL loss')
plt.legend()
plt.title('Total Loss Comparison')
plt.show()

# %%
plt.figure(figsize=(14, 5))
plt.plot(feature_losses, label='Feature Loss')
plt.legend()
plt.title('Feature Loss')
plt.show()

# %%
plt.figure(figsize=(14, 5))
plt.plot(cd_losses, label='Chamfer Loss')
plt.legend()
plt.title('Chamfer Loss')
plt.show()
